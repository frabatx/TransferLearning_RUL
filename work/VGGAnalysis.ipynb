# %% [markdown]
# # Transfer Learning in RUL Estimation
# ## Settings

# %%
## Import libraries in python
import argparse
import time
import json
import logging
import sys
import os
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import importlib
from itertools import repeat
from scipy.stats import randint, expon, uniform

import tensorflow as tf
import sklearn as sk
from sklearn import svm
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn import preprocessing
from sklearn import pipeline
from sklearn.metrics import mean_squared_error
from math import sqrt
import cv2
import io
from PIL import Image
from numba import jit, cuda


# Ignore tf err log
pd.options.mode.chained_assignment = None  # default='warn'
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)
tf.get_logger().setLevel(logging.ERROR)

# random seed predictable
seed = 0
random.seed(seed)
np.random.seed(seed)

# Path settings
current_dir = '.'#os.path.dirname(os.path.abspath(__file__))

## Dataset path
train_FD001_path = current_dir +'/cmapss/train_FD001.csv'
test_FD001_path = current_dir +'/cmapss/test_FD001.csv'
RUL_FD001_path = current_dir+'/cmapss/RUL_FD001.txt'
FD001_path = [train_FD001_path, test_FD001_path, RUL_FD001_path]

train_FD002_path = current_dir +'/cmapss/train_FD002.csv'
test_FD002_path = current_dir +'/cmapss/test_FD002.csv'
RUL_FD002_path = current_dir +'/cmapss/RUL_FD002.txt'
FD002_path = [train_FD002_path, test_FD002_path, RUL_FD002_path]

train_FD003_path = current_dir +'/cmapss/train_FD003.csv'
test_FD003_path = current_dir +'/cmapss/test_FD003.csv'
RUL_FD003_path = current_dir +'/cmapss/RUL_FD003.txt'
FD003_path = [train_FD003_path, test_FD003_path, RUL_FD003_path]

train_FD004_path =current_dir +'/cmapss/train_FD004.csv'
test_FD004_path = current_dir +'/cmapss/test_FD004.csv'
RUL_FD004_path = current_dir +'/cmapss/RUL_FD004.txt'
FD004_path = [train_FD004_path, test_FD004_path, RUL_FD004_path]

## Assign columns name
cols = ['unit_nr', 'cycles', 'os_1', 'os_2', 'os_3']
cols += ['sensor_{0:02d}'.format(s + 1) for s in range(26)]
col_rul = ['RUL_truth']

## Read csv file to pandas dataframe
FD_path = ["none", FD001_path, FD002_path, FD003_path, FD004_path]
dp_str = ["none", "FD001", "FD002", "FD003", "FD004"]

## temporary model path for NN
model_path = current_dir +'/temp_net.h5'

# Sensors not to be considered (those that do not disclose any pattern in their ts)
sensor_drop = ['sensor_01', 'sensor_05', 'sensor_06', 'sensor_10', 'sensor_16', 'sensor_18', 'sensor_19']

#start = time.time()

# Architecture preferences
dp = FD_path[1]
subdataset = dp_str[1]
sequence_length = 32
thres_type = None
thres_value = 50
device = 'cpu'
method = 'rps'
epochs = 50
batch = 100
verbose = 1
flatten = False
visualize = False

# %% [markdown]
# ## Recurrent Plot File

# %%
'''
Created on April , 2021
@author:
'''
import logging
import pandas as pd
import numpy as np
import joblib
import matplotlib.pyplot as plt
from pyts.image import RecurrencePlot
from sklearn import preprocessing
# from sklearn.decomposition import PCA
# from pyts.approximation import SymbolicFourierApproximation


def gen_sequence(id_df, seq_length, seq_cols):
    """ Only sequences that meet the window-length are considered, no padding is used. This means for testing
    we need to drop those which are below the window-length. An alternative would be to pad sequences so that
    we can use shorter ones """
    # for one id I put all the rows in a single matrix
    data_matrix = id_df[seq_cols].values
    num_elements = data_matrix.shape[0]
    # Iterate over two lists in parallel.

    for start, stop in zip(range(0, num_elements - seq_length), range(seq_length, num_elements)):
        yield data_matrix[start:stop, :]

def gen_labels(id_df, seq_length, label):
    """ Only sequences that meet the window-length are considered, no padding is used. This means for testing
    we need to drop those which are below the window-length. An alternative would be to pad sequences so that
    we can use shorter ones """
    # For one id I put all the labels in a single matrix.
    data_matrix = id_df[label].values
    num_elements = data_matrix.shape[0]
    # I have to remove the first seq_length labels
    # because for one id the first sequence of seq_length size have as target
    # the last label (the previus ones are discarded).
    # All the next id's sequences will have associated step by step one label as target.
    return data_matrix[seq_length:num_elements, :]



class input_gen(object):
    '''
    class for data preparation (rps generator)
    '''

    def __init__(self, data_path_list, sequence_length, sensor_drop, piecewise_lin_ref=125, preproc=False, visualize=True):
        '''
        :param data_path_list: python list of four sub-dataset
        :param sequence_length: legnth of sequence (sliced time series)
        :param sensor_drop: sensors not to be considered
        :param piecewise_lin_ref: max rul value (if real rul value is larger than piecewise_lin_ref,
        then the rul value is piecewise_lin_ref)
        :param preproc: preprocessing
        '''
        # self.__logger = logging.getLogger('data preparation for using it as the network input')
        self.data_path_list = data_path_list
        self.sequence_length = sequence_length
        self.sensor_drop = sensor_drop
        self.preproc = preproc
        self.piecewise_lin_ref = piecewise_lin_ref
        self.visualize = visualize


        ## Assign columns name
        cols = ['unit_nr', 'cycles', 'os_1', 'os_2', 'os_3']
        cols += ['sensor_{0:02d}'.format(s + 1) for s in range(26)]
        col_rul = ['RUL_truth']

        train_FD = pd.read_csv(self.data_path_list[0], sep=' ', header=None,
                               names=cols, index_col=False)
        test_FD = pd.read_csv(self.data_path_list[1], sep=' ', header=None,
                              names=cols, index_col=False)
        RUL_FD = pd.read_csv(self.data_path_list[2], sep=' ', header=None,
                             names=col_rul, index_col=False)

        ## Calculate RUL and append to train data
        # get the time of the last available measurement for each unit
        mapper = {}
        for unit_nr in train_FD['unit_nr'].unique():
            mapper[unit_nr] = train_FD['cycles'].loc[train_FD['unit_nr'] == unit_nr].max()

        # calculate RUL = time.max() - time_now for each unit
        train_FD['RUL'] = train_FD['unit_nr'].apply(lambda nr: mapper[nr]) - train_FD['cycles']
        # piecewise linear for RUL labels
        train_FD['RUL'].loc[(train_FD['RUL'] > self.piecewise_lin_ref)] = self.piecewise_lin_ref

        # Cut max RUL ground truth
        RUL_FD['RUL_truth'].loc[(RUL_FD['RUL_truth'] > self.piecewise_lin_ref)] = self.piecewise_lin_ref

        ## Excluse columns which only have NaN as value
        cols_nan = train_FD.columns[train_FD.isna().any()].tolist()
        cols_const = [col for col in train_FD.columns if len(train_FD[col].unique()) <= 2]

        ## Drop exclusive columns
        # train_FD = train_FD.drop(columns=cols_const + cols_nan)
        # test_FD = test_FD.drop(columns=cols_const + cols_nan)

        train_FD = train_FD.drop(columns=cols_const + cols_nan + sensor_drop)

        test_FD = test_FD.drop(columns=cols_const + cols_nan + sensor_drop)


        if self.preproc == True:
            ## preprocessing(normailization for the neural networks)
            min_max_scaler = preprocessing.MinMaxScaler()
            # for the training set
            # train_FD['cycles_norm'] = train_FD['cycles']
            cols_normalize = train_FD.columns.difference(['unit_nr', 'cycles', 'os_1', 'os_2', 'RUL'])

            norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(train_FD[cols_normalize]),
                                         columns=cols_normalize,
                                         index=train_FD.index)
            join_df = train_FD[train_FD.columns.difference(cols_normalize)].join(norm_train_df)
            train_FD = join_df.reindex(columns=train_FD.columns)

            # for the test set
            # test_FD['cycles_norm'] = test_FD['cycles']
            cols_normalize_test = test_FD.columns.difference(['unit_nr', 'cycles', 'os_1', 'os_2'])
            # print ("cols_normalize_test", cols_normalize_test)
            norm_test_df = pd.DataFrame(min_max_scaler.transform(test_FD[cols_normalize_test]), columns=cols_normalize_test,
                                        index=test_FD.index)
            test_join_df = test_FD[test_FD.columns.difference(cols_normalize_test)].join(norm_test_df)
            test_FD = test_join_df.reindex(columns=test_FD.columns)
            test_FD = test_FD.reset_index(drop=True)
        else:
            # print ("No preprocessing")
            pass

        # Specify the columns to be used
        sequence_cols_train = train_FD.columns.difference(['unit_nr', 'cycles', 'os_1', 'os_2', 'RUL'])
        sequence_cols_test = test_FD.columns.difference(['unit_nr', 'os_1', 'os_2', 'cycles'])



        ## generator for the sequences
        # transform each id of the train dataset in a sequence
        seq_gen = (list(gen_sequence(train_FD[train_FD['unit_nr'] == id], self.sequence_length, sequence_cols_train))
                   for id in train_FD['unit_nr'].unique())

        # generate sequences and convert to numpy array in training set
        seq_array_train = np.concatenate(list(seq_gen)).astype(np.float32)
        self.seq_array_train = seq_array_train.transpose(0, 2, 1) # shape = (samples, sensors, sequences)
        # print("seq_array_train.shape", self.seq_array_train.shape)

        # generate label of training samples
        label_gen = [gen_labels(train_FD[train_FD['unit_nr'] == id], self.sequence_length, ['RUL'])
                     for id in train_FD['unit_nr'].unique()]
        self.label_array_train = np.concatenate(label_gen).astype(np.float32)

        # generate sequences and convert to numpy array in test set (only the last sequence for each engine in test set)
        seq_array_test_last = [test_FD[test_FD['unit_nr'] == id][sequence_cols_test].values[-self.sequence_length:]
                               for id in test_FD['unit_nr'].unique() if
                               len(test_FD[test_FD['unit_nr'] == id]) >= self.sequence_length]

        seq_array_test_last = np.asarray(seq_array_test_last).astype(np.float32)
        self.seq_array_test_last = seq_array_test_last.transpose(0, 2, 1) # shape = (samples, sensors, sequences)
        # print("seq_array_test_last.shape", self.seq_array_test_last.shape)

        # generate label of test samples
        y_mask = [len(test_FD[test_FD['unit_nr'] == id]) >= self.sequence_length for id in test_FD['unit_nr'].unique()]
        label_array_test_last = RUL_FD['RUL_truth'][y_mask].values
        self.label_array_test = label_array_test_last.reshape(label_array_test_last.shape[0], 1).astype(np.float32)


        ## Visualize Run-2-failure TS of the first engine in the training set.(Please deactivate after understanding)
        if self.visualize == True:
            # R2F TS of the first engine
            pd.DataFrame(train_FD[train_FD['unit_nr'] == 1][sequence_cols_train].values,
                             columns=sequence_cols_train).plot(subplots=True, figsize=(15, 15))

            # The last sequences sliced from each TS (of the first engine)
            prop_cycle = plt.rcParams['axes.prop_cycle']
            colors = prop_cycle.by_key()['color']
            colors = colors + colors + colors

            seq_gen = (
            list(gen_sequence(train_FD[train_FD['unit_nr'] == id], self.sequence_length, sequence_cols_train))
            for id in train_FD['unit_nr'].unique())

            seq_list_engine = list(seq_gen)
            seq_engine_1_array = np.asarray(seq_list_engine[0])

            last_seq_engine_1_array = seq_engine_1_array[-1, :, :]
            fig_ts = plt.figure(figsize=(15, 15))
            for s in range(last_seq_engine_1_array.shape[1]):
                seq_s = last_seq_engine_1_array[:, s]
                # plt.subplot(last_seq_engine_1_array.shape[1],(s//4) + 1, (s%4)+1)
                plt.subplot(4, 4, s + 1)
                plt.plot(seq_s, "y", label=sequence_cols_train[s], color=colors[s])
                plt.legend()

            plt.xlabel("time(cycles)")
            plt.show()


    def rps(self, thres_type=None, thres_percentage=50, flatten=False, visualize=True):
        '''
        generate RPs from sequences
        :param thres_type:  ‘point’, ‘distance’ or None (default = None)
        :param thres_percentage:
        :param flatten:
        :param visualize: visualize generated RPs (first training sample)
        :return: PRs (samples for NNs and their label)
        '''

        # Recurrence plot transformation for training samples
        rp_train = RecurrencePlot(threshold=thres_type, percentage=thres_percentage,flatten=flatten)

        rp_list = []
        for idx in range(self.seq_array_train.shape[0]):
            temp_mts = self.seq_array_train[idx]
            # print (temp_mts.shape)
            X_rp_temp = rp_train.fit_transform(temp_mts)
            # print (X_rp_temp.shape)
            rp_list.append(X_rp_temp)

        rp_train_samples = np.stack(rp_list, axis=0)

        # Recurrence plot transformation for test samples
        rp_test = RecurrencePlot(threshold=thres_type, percentage=thres_percentage, flatten=flatten)
        rp_list = []
        for idx in range(self.seq_array_test_last.shape[0]):
            temp_mts = self.seq_array_test_last[idx]
            # print (temp_mts.shape)
            X_rp_temp = rp_test.fit_transform(temp_mts)
            # print (X_rp_temp.shape)
            rp_list.append(X_rp_temp)
        rp_test_samples = np.stack(rp_list, axis=0)

        label_array_train = self.label_array_train
        label_array_test = self.label_array_test

        # Visualize RPs of the last sequences sliced from each TS (of the first engine)
        if visualize == True:
            X_rp = rp_train_samples[-1]
            plt.figure(figsize=(15, 15))
            for s in range(len(X_rp)):
                # plt.subplot(last_seq_engine_1_array.shape[1],(s//4) + 1, (s%4)+1)
                plt.subplot(4, 4, s + 1)
                if flatten == True:
                    img = np.atleast_2d(X_rp[s])
                    plt.imshow(img, extent=(0, img.shape[1], 0, round(img.shape[1]/9)))
                else:
                    plt.imshow(X_rp[s], origin='lower')
                # plt.legend()
            plt.show()

        return  rp_train_samples, label_array_train, rp_test_samples, label_array_test

# %%
data_class = input_gen(data_path_list=dp, 
                       sequence_length=sequence_length,
                       preproc = True, 
                       sensor_drop= sensor_drop, 
                       visualize=visualize)

# %%
if method == 'rps':
    train_samples, label_array_train, test_samples, label_array_test = data_class.rps(
        thres_type=thres_type,
        thres_percentage=thres_value,
        flatten=flatten,
        visualize=visualize)

elif method == 'jrp': # please implement any method if needed
    pass

# %%
train_samples.shape
# Out:
# (17431, 14, 32, 32)

# %%
# def change_format(X_rp):
#     '''
#     Takes 14 sensors array (32x32) and reshapes into 1 array(128x128)
#     '''
#     # 1- Create two dummy zero arrays with np.zeros(32,32)
#     temp = np.zeros((64,32))
#     # 2- Concatenate all 16 arrays
#     for i in range(len(X_rp)):
#         x = X_rp[i]
#         temp = np.concatenate((temp,x), axis=0)

#     # 3- Reshape the concatenated arrays to (128,128)
#     new_train0 = temp.reshape(128,128)
#     # 4- Extract RGB channels with cv2.split(img)
#     ## To make a figure without the frame
#     my_dpi = 96
#     array_size = 128
#     fig = plt.figure(figsize=(array_size/my_dpi, array_size/my_dpi), dpi=my_dpi, frameon=False)
#     ## To make the content fill the whole figure
#     ax = plt.Axes(fig, [0., 0., 1., 1.])
#     ax.set_axis_off()
#     fig.add_axes(ax)
#     ## Drawing image
#     ax.imshow(new_train0)
#     fig.savefig('img1.png', dpi = my_dpi)
#     img = cv2.imread('img1.png')
#     plt.close(fig)
    
#     return np.asarray(cv2.split(img))

def change_format(X_rp):
    '''
    Takes 14 sensors array (32x32) and reshapes into 1 array(128x128)
    '''
    dummy_array = np.zeros((64,32))
    temp_row = np.array([]).reshape(0,len(X_rp[0]))
    temp_array = np.array([]).reshape(len(X_rp[0])*4,0)
    for i in range(len(X_rp)):
    # print ("temp_row.shape", temp_row.shape)
    # print ("temp_array.shape", temp_array.shape)        
        x = X_rp[i]
        # temp_row = np.concatenate((temp_row,x), axis=0)
        temp_row = np.vstack([temp_row,x])
        if (i+1)%4 == 0:
            temp_array = np.hstack([temp_array, temp_row])
            temp_row = np.array([]).reshape(0,len(X_rp[0]))
        if (i+1)==len(X_rp):
            temp_row = np.vstack([temp_row,dummy_array])
            temp_array = np.hstack([temp_array, temp_row])
            temp_row = np.array([]).reshape(0,len(X_rp[0]))   
    # plt.figure(figsize=(10, 10))
    # plt.imshow(temp_array, origin='lower')
    # plt.show()
    new_train0 = temp_array
    # 4- Extract RGB channels with cv2.split(img)
    ## To make a figure without the frame
    my_dpi = 96
    array_size = 128
    fig = plt.figure(figsize=(array_size/my_dpi, array_size/my_dpi), dpi=my_dpi, frameon=False)
    ## To make the content fill the whole figure
    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    ## Drawing image
    ax.imshow(new_train0)
    fig.savefig('img1.png', dpi = my_dpi)
    img = cv2.imread('img1.png')
    plt.close(fig)
    return  np.asarray(cv2.split(img))

# %%
def timer(start,end):
    hours, rem = divmod(end-start, 3600)
    minutes, seconds = divmod(rem, 60)
    print("{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds))

def format_samples(train_samples, test_samples):
    '''
    Format training and test sets (n_samples, image_size, channels)
    '''
    start = time.time()
    resh_train = np.asarray([change_format(rp) for rp in train_samples])
    end = time.time()
    print("Reshape train time: ")
    timer(start,end)
    start = time.time()
    resh_test = np.asarray([change_format(rp) for rp in test_samples])
    end = time.time()
    print("Reshape test time: ")
    timer(start,end)
    return resh_train, resh_test

# %%
train_samples, test_samples = format_samples(train_samples, test_samples)
# Out:
# Reshape train time:
# 00:07:46.24
# Reshape test time:
# 00:00:02.50

# %%
print ("train_samples.shape: ", train_samples.shape) # shape = (samples, channels, height, width)
print ("label_array_train.shape: ", label_array_train.shape) # shape = (samples, label)
print ("test_samples.shape: ", test_samples.shape) # shape = (samples, channels, height, width)
print ("label_array_test.shape: ", label_array_test.shape) # shape = (samples, ground truth)

train_samples = np.transpose(train_samples, (0,2,3,1))
test_samples = np.transpose(test_samples, (0,2,3,1))

print ("train_samples.shape: ", train_samples.shape) # shape = (samples, height, width, channels)
print ("label_array_train.shape: ", label_array_train.shape) # shape = (samples, label)
print ("test_samples.shape: ", test_samples.shape) # shape = (samples, height, width, channels)
print ("label_array_test.shape: ", label_array_test.shape) # shape = (samples, ground truth)
# Out:
# train_samples.shape:  (17431, 3, 128, 128)
# label_array_train.shape:  (17431, 1)
# test_samples.shape:  (99, 3, 128, 128)
# label_array_test.shape:  (99, 1)
# train_samples.shape:  (17431, 128, 128, 3)
# label_array_train.shape:  (17431, 1)
# test_samples.shape:  (99, 128, 128, 3)
# label_array_test.shape:  (99, 1)

# %% [markdown]
# # Network

# %%
import time
import json
import logging as log
import sys

import os
import math
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
import importlib
from scipy.stats import randint, expon, uniform

import sklearn as sk
from sklearn import svm
from sklearn.utils import shuffle
from sklearn import metrics
from sklearn import preprocessing
from sklearn import pipeline
from sklearn.metrics import mean_squared_error

from math import sqrt
# import keras
import tensorflow as tf
print(tf.__version__)

# import keras.backend as K
import tensorflow.keras.backend as K
from tensorflow.keras import backend
from tensorflow.keras import optimizers
from tensorflow.keras.models import Sequential, load_model, Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.layers import Input, Dense, Flatten, Dropout, Embedding
from tensorflow.keras.layers import BatchNormalization, Activation, LSTM, TimeDistributed
from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

np.random.seed(0)
tf.random.set_seed(0)


def gen_net(model_name, weights, freeze):
    '''
    TODO: Implement other cnn model
    Todo: Freezing only few layers (read papers)
    :param model_name: vgg, inception
    :param weights: True/False
    :param pretrain: True/False
    :return:
    '''
    
    if(model_name == "vgg"):
        if(weights == True):
            model = VGG16(
                input_shape=(128,128,3), 
                weights = 'imagenet', 
                include_top = False)
        else:
            model = VGG16(
                input_shape=(128,128,3), 
                weights = None, 
                include_top = False)
    
    if(model_name == "inception"):
        if(weights == True):
            model = InceptionV3(
                input_shape=(128,128,3), 
                weights = 'imagenet', 
                include_top = False)
        else:
            model = InceptionV3(
                input_shape=(128,128,3),
                weights = None, 
                include_top = False)

    # This section has to be modified in order a pre defined number of layers
    if(freeze):
        for layer in model.layers:
            layer.trainable = False

    
    base_outputs = model.output
    flatten_outputs = Flatten()(base_outputs)
    final_outputs = Dense(1)(flatten_outputs)
    new_model = Model(inputs = model.input, outputs = final_outputs) 
    new_model.summary()

    return new_model


# def gen_net(vec_len, num_hidden1, num_hidden2 ):
#     '''
#     TODO: Generate and evaluate any CNN instead of MLPs
#     :param vec_len:
#     :param num_hidden1:
#     :param num_hidden2:
#     :return:
#     '''

#     model = Sequential()
#     model.add(Dense(num_hidden1, activation='relu', input_shape=(vec_len,)))
#     model.add(Dense(num_hidden2, activation='relu'))
#     model.add(Dense(1))

#     return model

class network_fit(object):
    '''
    class for network
    '''

    def __init__(self, train_samples, label_array_train, test_samples, label_array_test,
                 model_path, model_name, weights, freeze, verbose=1):
        '''
        Constructor
        Generate a CNN and train
        @param none
        '''
        # self.__logger = logging.getLogger('data preparation for using it as the network input')
        self.train_samples = train_samples
        self.label_array_train = label_array_train
        self.test_samples = test_samples
        self.label_array_test = label_array_test
        self.model_path = model_path
        self.verbose = verbose

        # self.mlps = gen_net(self.train_samples.shape[1], self.n_hidden1, self.n_hidden2)
        self.mlps = gen_net(model_name, weights, freeze)



    def train_net(self, epochs, batch_size, lr= 1e-05, plotting=False):
        '''
        specify the optimizers and train the network
        :param epochs:
        :param batch_size:
        :param lr:
        :return:
        '''
        print("Initializing network...")
        # compile the model
        rp = optimizers.RMSprop(learning_rate=lr, rho=0.9, centered=True)
        adm = optimizers.Adam(learning_rate=lr, epsilon=1)
        sgd_m = optimizers.SGD(learning_rate=lr)

        keras_rmse = tf.keras.metrics.RootMeanSquaredError()
        self.mlps.compile(loss='mean_squared_error', optimizer=adm, metrics=[keras_rmse, 'mae'])

        print(self.mlps.summary())

        # Train the model
        history = self.mlps.fit(self.train_samples, self.label_array_train, epochs=epochs, batch_size=batch_size,
                                validation_split=0.2, verbose=self.verbose,
                                callbacks=[
                               EarlyStopping(monitor='val_root_mean_squared_error', min_delta=0, patience=50, verbose=self.verbose, mode='min'),
                               ModelCheckpoint(self.model_path, monitor='val_root_mean_squared_error', save_best_only=True, mode='min',
                                               verbose=self.verbose)])

        val_rmse_k = history.history['val_root_mean_squared_error']
        val_rmse_min = min(val_rmse_k)
        min_val_rmse_idx = val_rmse_k.index(min(val_rmse_k))
        stop_epoch = min_val_rmse_idx +1
        val_rmse_min = round(val_rmse_min, 4)
        print ("val_rmse_min: ", val_rmse_min)

        trained_net = self.mlps

        ## Plot training & validation loss about epochs
        if plotting == True:
            # summarize history for Loss
            fig_acc = plt.figure(figsize=(10, 10))
            plt.plot(history.history['loss'])
            plt.plot(history.history['val_loss'])
            plt.title('model loss')
            plt.ylabel('loss')
            plt.ylim(0, 2000)
            plt.xlabel('epoch')
            plt.legend(['train', 'test'], loc='upper left')
            plt.show()


        return trained_net



    def test_net(self, trained_net=None, best_model=True, plotting=True):
        '''
        Evalute the trained network on test set
        :param trained_net:
        :param best_model:
        :param plotting:
        :return:
        '''
        # Load the trained model
        if best_model:
            estimator = load_model(self.model_path)
        else:
            estimator = load_model(trained_net)

        # predict the RUL
        y_pred_test = estimator.predict(self.test_samples)
        y_true_test = self.label_array_test # ground truth of test samples

        pd.set_option('display.max_rows', 1000)
        test_print = pd.DataFrame()
        test_print['y_pred'] = y_pred_test.flatten()
        test_print['y_truth'] = y_true_test.flatten()
        test_print['diff'] = abs(y_pred_test.flatten() - y_true_test.flatten())
        test_print['diff(ratio)'] = abs(y_pred_test.flatten() - y_true_test.flatten()) / y_true_test.flatten()
        test_print['diff(%)'] = (abs(y_pred_test.flatten() - y_true_test.flatten()) / y_true_test.flatten()) * 100

        y_predicted = test_print['y_pred']
        y_actual = test_print['y_truth']
        rms = sqrt(mean_squared_error(y_actual, y_predicted)) # RMSE metric
        test_print['rmse'] = rms
        print(test_print)


        # Score metric
        h_array = y_predicted - y_actual
        s_array = np.zeros(len(h_array))
        for j, h_j in enumerate(h_array):
            if h_j < 0:
                s_array[j] = math.exp(-(h_j / 13)) - 1

            else:
                s_array[j] = math.exp(h_j / 10) - 1
        score = np.sum(s_array)

        # Plot the results of RUL prediction
        if plotting == True:
            fig_verify = plt.figure(figsize=(12, 6))
            plt.plot(y_pred_test, color="blue")
            plt.plot(y_true_test, color="green")
            plt.title('prediction')
            plt.ylabel('value')
            plt.xlabel('row')
            plt.legend(['predicted', 'actual data'], loc='upper left')
            plt.show()

        return rms, score
# Out:
# 2.4.1

# %% [markdown]
# ## VGG + Weights + Freeze

# %%
# Creo l'oggetto net
mlps_net = network_fit(train_samples, 
                       label_array_train, 
                       test_samples, 
                       label_array_test,
                       model_path = model_path, 
                       model_name = "vgg",
                       weights = True,
                       freeze = True,
                       verbose=verbose)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 128, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 128, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 8193
# =================================================================
# Total params: 14,722,881
# Trainable params: 8,193
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
#Train
trained_net = mlps_net.train_net(epochs=epochs, batch_size=batch)
# Out:
# Initializing network...
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 128, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 128, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 8192)              0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 8193
# =================================================================
# Total params: 14,722,881
# Trainable params: 8,193
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None
# Epoch 1/50
# 140/140 [==============================] - 52s 298ms/step - loss: 7922.2021 - root_mean_squared_error: 88.9911 - mae: 78.2609 - val_loss: 7003.1514 - val_root_mean_squared_error: 83.6848 - val_mae: 72.9736
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 83.68484, saving model to ./temp_net.h5
# Epoch 2/50
# 140/140 [==============================] - 30s 212ms/step - loss: 5742.6244 - root_mean_squared_error: 75.7576 - mae: 64.7964 - val_loss: 5100.4902 - val_root_mean_squared_error: 71.4177 - val_mae: 61.5450
#
# Epoch 00002: val_root_mean_squared_error improved from 83.68484 to 71.41772, saving model to ./temp_net.h5
# Epoch 3/50
# 140/140 [==============================] - 30s 213ms/step - loss: 4226.6653 - root_mean_squared_error: 64.9891 - mae: 55.3938 - val_loss: 3813.9399 - val_root_mean_squared_error: 61.7571 - val_mae: 53.2613
#
# Epoch 00003: val_root_mean_squared_error improved from 71.41772 to 61.75710, saving model to ./temp_net.h5
# Epoch 4/50
# 140/140 [==============================] - 30s 213ms/step - loss: 3141.4699 - root_mean_squared_error: 56.0403 - mae: 47.8564 - val_loss: 2978.7280 - val_root_mean_squared_error: 54.5777 - val_mae: 47.6583
#
# Epoch 00004: val_root_mean_squared_error improved from 61.75710 to 54.57772, saving model to ./temp_net.h5
# Epoch 5/50
# 140/140 [==============================] - 30s 213ms/step - loss: 2556.5237 - root_mean_squared_error: 50.5532 - mae: 43.8144 - val_loss: 2464.6370 - val_root_mean_squared_error: 49.6451 - val_mae: 44.0360
#
# Epoch 00005: val_root_mean_squared_error improved from 54.57772 to 49.64511, saving model to ./temp_net.h5
# Epoch 6/50
# 140/140 [==============================] - 30s 213ms/step - loss: 2190.7607 - root_mean_squared_error: 46.8017 - mae: 41.1715 - val_loss: 2156.3660 - val_root_mean_squared_error: 46.4367 - val_mae: 41.6766
#
# Epoch 00006: val_root_mean_squared_error improved from 49.64511 to 46.43669, saving model to ./temp_net.h5
# Epoch 7/50
# 140/140 [==============================] - 30s 214ms/step - loss: 1963.8917 - root_mean_squared_error: 44.3138 - mae: 39.1397 - val_loss: 1973.5219 - val_root_mean_squared_error: 44.4243 - val_mae: 40.0867
#
# Epoch 00007: val_root_mean_squared_error improved from 46.43669 to 44.42434, saving model to ./temp_net.h5
# Epoch 8/50
# 140/140 [==============================] - 30s 213ms/step - loss: 1836.3675 - root_mean_squared_error: 42.8524 - mae: 37.9319 - val_loss: 1861.6594 - val_root_mean_squared_error: 43.1469 - val_mae: 38.9955
#
# Epoch 00008: val_root_mean_squared_error improved from 44.42434 to 43.14695, saving model to ./temp_net.h5
# Epoch 9/50
# 140/140 [==============================] - 30s 213ms/step - loss: 1781.4860 - root_mean_squared_error: 42.2072 - mae: 37.3781 - val_loss: 1789.1642 - val_root_mean_squared_error: 42.2985 - val_mae: 38.2221
#
# Epoch 00009: val_root_mean_squared_error improved from 43.14695 to 42.29851, saving model to ./temp_net.h5
# Epoch 10/50
# 140/140 [==============================] - 30s 215ms/step - loss: 1715.7787 - root_mean_squared_error: 41.4215 - mae: 36.7266 - val_loss: 1736.9226 - val_root_mean_squared_error: 41.6764 - val_mae: 37.6410
#
# Epoch 00010: val_root_mean_squared_error improved from 42.29851 to 41.67640, saving model to ./temp_net.h5
# Epoch 11/50
# 140/140 [==============================] - 30s 213ms/step - loss: 1682.7205 - root_mean_squared_error: 41.0204 - mae: 36.3974 - val_loss: 1695.6044 - val_root_mean_squared_error: 41.1777 - val_mae: 37.1775
#
# Epoch 00011: val_root_mean_squared_error improved from 41.67640 to 41.17772, saving model to ./temp_net.h5
# Epoch 12/50
# 140/140 [==============================] - 30s 214ms/step - loss: 1640.2996 - root_mean_squared_error: 40.5001 - mae: 35.9627 - val_loss: 1657.5404 - val_root_mean_squared_error: 40.7129 - val_mae: 36.7473
#
# Epoch 00012: val_root_mean_squared_error improved from 41.17772 to 40.71290, saving model to ./temp_net.h5
# Epoch 13/50
# 140/140 [==============================] - 30s 214ms/step - loss: 1605.7538 - root_mean_squared_error: 40.0714 - mae: 35.5130 - val_loss: 1621.7028 - val_root_mean_squared_error: 40.2704 - val_mae: 36.3402
#
# Epoch 00013: val_root_mean_squared_error improved from 40.71290 to 40.27037, saving model to ./temp_net.h5
# Epoch 14/50
# 140/140 [==============================] - 30s 214ms/step - loss: 1572.3393 - root_mean_squared_error: 39.6510 - mae: 35.2493 - val_loss: 1587.9082 - val_root_mean_squared_error: 39.8486 - val_mae: 35.9559
#
# Epoch 00014: val_root_mean_squared_error improved from 40.27037 to 39.84857, saving model to ./temp_net.h5
# Epoch 15/50
# 140/140 [==============================] - 30s 214ms/step - loss: 1523.1015 - root_mean_squared_error: 39.0268 - mae: 34.6583 - val_loss: 1556.8875 - val_root_mean_squared_error: 39.4574 - val_mae: 35.6075
#
# Epoch 00015: val_root_mean_squared_error improved from 39.84857 to 39.45741, saving model to ./temp_net.h5
# Epoch 16/50
# 140/140 [==============================] - 30s 213ms/step - loss: 1476.6095 - root_mean_squared_error: 38.4262 - mae: 34.0745 - val_loss: 1525.7197 - val_root_mean_squared_error: 39.0605 - val_mae: 35.2486
# Epoch 00016: val_root_mean_squared_error improved from 39.45741 to 39.06046, saving model to ./temp_net.h5
# Epoch 17/50
# 140/140 [==============================] - 30s 213ms/step - loss: 1446.9527 - root_mean_squared_error: 38.0384 - mae: 33.8152 - val_loss: 1493.0630 - val_root_mean_squared_error: 38.6402 - val_mae: 34.8599
#
# Epoch 00017: val_root_mean_squared_error improved from 39.06046 to 38.64017, saving model to ./temp_net.h5
# Epoch 18/50
# 140/140 [==============================] - 30s 214ms/step - loss: 1417.4988 - root_mean_squared_error: 37.6493 - mae: 33.4377 - val_loss: 1462.5353 - val_root_mean_squared_error: 38.2431 - val_mae: 34.4965
#
# Epoch 00018: val_root_mean_squared_error improved from 38.64017 to 38.24311, saving model to ./temp_net.h5
# Epoch 19/50
# 140/140 [==============================] - 30s 214ms/step - loss: 1363.5114 - root_mean_squared_error: 36.9250 - mae: 32.8146 - val_loss: 1433.7667 - val_root_mean_squared_error: 37.8651 - val_mae: 34.1491
#
# Epoch 00019: val_root_mean_squared_error improved from 38.24311 to 37.86511, saving model to ./temp_net.h5
# Epoch 20/50
# 140/140 [==============================] - 30s 213ms/step - loss: 1345.0867 - root_mean_squared_error: 36.6746 - mae: 32.7585 - val_loss: 1403.9893 - val_root_mean_squared_error: 37.4698 - val_mae: 33.7804
#
# Epoch 00020: val_root_mean_squared_error improved from 37.86511 to 37.46984, saving model to ./temp_net.h5
# Epoch 21/50
# 140/140 [==============================] - 30s 214ms/step - loss: 1311.6397 - root_mean_squared_error: 36.2160 - mae: 32.1772 - val_loss: 1374.0963 - val_root_mean_squared_error: 37.0688 - val_mae: 33.4016
#
# Epoch 00021: val_root_mean_squared_error improved from 37.46984 to 37.06881, saving model to ./temp_net.h5
# Epoch 22/50
# 140/140 [==============================] - 30s 215ms/step - loss: 1292.1136 - root_mean_squared_error: 35.9449 - mae: 31.9492 - val_loss: 1347.4352 - val_root_mean_squared_error: 36.7074 - val_mae: 33.0627
#
# Epoch 00022: val_root_mean_squared_error improved from 37.06881 to 36.70742, saving model to ./temp_net.h5
# Epoch 23/50
# 140/140 [==============================] - 30s 214ms/step - loss: 1262.0818 - root_mean_squared_error: 35.5243 - mae: 31.6364 - val_loss: 1317.8969 - val_root_mean_squared_error: 36.3028 - val_mae: 32.6715
#
# Epoch 00023: val_root_mean_squared_error improved from 36.70742 to 36.30285, saving model to ./temp_net.h5
# Epoch 24/50
# 140/140 [==============================] - 30s 214ms/step - loss: 1211.0135 - root_mean_squared_error: 34.7987 - mae: 30.8641 - val_loss: 1291.1632 - val_root_mean_squared_error: 35.9328 - val_mae: 32.3149
#
# Epoch 00024: val_root_mean_squared_error improved from 36.30285 to 35.93276, saving model to ./temp_net.h5
# Epoch 25/50
# 140/140 [==============================] - 30s 213ms/step - loss: 1170.5057 - root_mean_squared_error: 34.2113 - mae: 30.2663 - val_loss: 1265.2345 - val_root_mean_squared_error: 35.5701 - val_mae: 31.9623
#
# Epoch 00025: val_root_mean_squared_error improved from 35.93276 to 35.57013, saving model to ./temp_net.h5
# Epoch 26/50
# 140/140 [==============================] - 30s 214ms/step - loss: 1159.3957 - root_mean_squared_error: 34.0490 - mae: 30.1875 - val_loss: 1239.7194 - val_root_mean_squared_error: 35.2096 - val_mae: 31.6079
#
# Epoch 00026: val_root_mean_squared_error improved from 35.57013 to 35.20965, saving model to ./temp_net.h5
# Epoch 27/50
# 140/140 [==============================] - 30s 213ms/step - loss: 1120.4768 - root_mean_squared_error: 33.4729 - mae: 29.6554 - val_loss: 1217.8464 - val_root_mean_squared_error: 34.8977 - val_mae: 31.2956
#
# Epoch 00027: val_root_mean_squared_error improved from 35.20965 to 34.89766, saving model to ./temp_net.h5
# Epoch 28/50
# 140/140 [==============================] - 30s 214ms/step - loss: 1106.3281 - root_mean_squared_error: 33.2603 - mae: 29.3987 - val_loss: 1192.9816 - val_root_mean_squared_error: 34.5396 - val_mae: 30.9360
#
# Epoch 00028: val_root_mean_squared_error improved from 34.89766 to 34.53957, saving model to ./temp_net.h5
# Epoch 29/50
# 140/140 [==============================] - 30s 214ms/step - loss: 1076.0256 - root_mean_squared_error: 32.8025 - mae: 28.8770 - val_loss: 1174.8676 - val_root_mean_squared_error: 34.2763 - val_mae: 30.6612
#
# Epoch 00029: val_root_mean_squared_error improved from 34.53957 to 34.27634, saving model to ./temp_net.h5
# Epoch 30/50
# 140/140 [==============================] - 30s 214ms/step - loss: 1050.5826 - root_mean_squared_error: 32.4124 - mae: 28.5361 - val_loss: 1153.4706 - val_root_mean_squared_error: 33.9628 - val_mae: 30.3361
#
# Epoch 00030: val_root_mean_squared_error improved from 34.27634 to 33.96278, saving model to ./temp_net.h5
# Epoch 31/50
# 140/140 [==============================] - 30s 214ms/step - loss: 1019.5604 - root_mean_squared_error: 31.9298 - mae: 27.9948 - val_loss: 1133.9038 - val_root_mean_squared_error: 33.6735 - val_mae: 30.0316
#
# Epoch 00031: val_root_mean_squared_error improved from 33.96278 to 33.67349, saving model to ./temp_net.h5
# Epoch 32/50
# 140/140 [==============================] - 30s 213ms/step - loss: 1025.1789 - root_mean_squared_error: 32.0158 - mae: 28.0632 - val_loss: 1110.7152 - val_root_mean_squared_error: 33.3274 - val_mae: 29.6769
#
# Epoch 00032: val_root_mean_squared_error improved from 33.67349 to 33.32739, saving model to ./temp_net.h5
# Epoch 33/50
# 140/140 [==============================] - 30s 213ms/step - loss: 992.0218 - root_mean_squared_error: 31.4962 - mae: 27.5672 - val_loss: 1093.7177 - val_root_mean_squared_error: 33.0714 - val_mae: 29.4059
#
# Epoch 00033: val_root_mean_squared_error improved from 33.32739 to 33.07140, saving model to ./temp_net.h5
# Epoch 34/50
# 140/140 [==============================] - 30s 214ms/step - loss: 977.6552 - root_mean_squared_error: 31.2671 - mae: 27.3042 - val_loss: 1078.1803 - val_root_mean_squared_error: 32.8357 - val_mae: 29.1524
#
# Epoch 00034: val_root_mean_squared_error improved from 33.07140 to 32.83566, saving model to ./temp_net.h5
# Epoch 35/50
# 140/140 [==============================] - 30s 214ms/step - loss: 967.1414 - root_mean_squared_error: 31.0966 - mae: 27.1345 - val_loss: 1063.1339 - val_root_mean_squared_error: 32.6057 - val_mae: 28.9058
#
# Epoch 00035: val_root_mean_squared_error improved from 32.83566 to 32.60574, saving model to ./temp_net.h5
# Epoch 36/50
# 140/140 [==============================] - 30s 213ms/step - loss: 963.0259 - root_mean_squared_error: 31.0257 - mae: 26.9546 - val_loss: 1046.2117 - val_root_mean_squared_error: 32.3452 - val_mae: 28.6315
#
# Epoch 00036: val_root_mean_squared_error improved from 32.60574 to 32.34520, saving model to ./temp_net.h5
# Epoch 37/50
# 140/140 [==============================] - 30s 213ms/step - loss: 919.8935 - root_mean_squared_error: 30.3284 - mae: 26.2642 - val_loss: 1033.3654 - val_root_mean_squared_error: 32.1460 - val_mae: 28.4097
#
# Epoch 00037: val_root_mean_squared_error improved from 32.34520 to 32.14600, saving model to ./temp_net.h5
# Epoch 38/50
# 140/140 [==============================] - 30s 214ms/step - loss: 902.0421 - root_mean_squared_error: 30.0335 - mae: 25.9399 - val_loss: 1019.8917 - val_root_mean_squared_error: 31.9357 - val_mae: 28.1791
#
# Epoch 00038: val_root_mean_squared_error improved from 32.14600 to 31.93574, saving model to ./temp_net.h5
# Epoch 39/50
# 140/140 [==============================] - 30s 214ms/step - loss: 898.3227 - root_mean_squared_error: 29.9692 - mae: 25.8447 - val_loss: 1007.2741 - val_root_mean_squared_error: 31.7376 - val_mae: 27.9575
#
# Epoch 00039: val_root_mean_squared_error improved from 31.93574 to 31.73758, saving model to ./temp_net.h5
# Epoch 40/50
# 140/140 [==============================] - 30s 213ms/step - loss: 892.1785 - root_mean_squared_error: 29.8674 - mae: 25.5904 - val_loss: 994.0825 - val_root_mean_squared_error: 31.5291 - val_mae: 27.7280
#
# Epoch 00040: val_root_mean_squared_error improved from 31.73758 to 31.52907, saving model to ./temp_net.h5
# Epoch 41/50
# 140/140 [==============================] - 30s 214ms/step - loss: 865.8542 - root_mean_squared_error: 29.4247 - mae: 25.2360 - val_loss: 982.6301 - val_root_mean_squared_error: 31.3469 - val_mae: 27.5192
#
# Epoch 00041: val_root_mean_squared_error improved from 31.52907 to 31.34693, saving model to ./temp_net.h5
# Epoch 42/50
# 140/140 [==============================] - 30s 213ms/step - loss: 847.0474 - root_mean_squared_error: 29.1031 - mae: 24.8640 - val_loss: 974.3559 - val_root_mean_squared_error: 31.2147 - val_mae: 27.3565
#
# Epoch 00042: val_root_mean_squared_error improved from 31.34693 to 31.21467, saving model to ./temp_net.h5
# Epoch 43/50
# 140/140 [==============================] - 30s 214ms/step - loss: 838.8265 - root_mean_squared_error: 28.9619 - mae: 24.6946 - val_loss: 964.8202 - val_root_mean_squared_error: 31.0616 - val_mae: 27.1771
#
# Epoch 00043: val_root_mean_squared_error improved from 31.21467 to 31.06155, saving model to ./temp_net.h5
# Epoch 44/50
# 140/140 [==============================] - 30s 214ms/step - loss: 834.1879 - root_mean_squared_error: 28.8815 - mae: 24.6140 - val_loss: 955.5107 - val_root_mean_squared_error: 30.9113 - val_mae: 27.0015
#
# Epoch 00044: val_root_mean_squared_error improved from 31.06155 to 30.91134, saving model to ./temp_net.h5
# Epoch 45/50
# 140/140 [==============================] - 30s 214ms/step - loss: 820.5948 - root_mean_squared_error: 28.6454 - mae: 24.3510 - val_loss: 948.5117 - val_root_mean_squared_error: 30.7979 - val_mae: 26.8633
#
# Epoch 00045: val_root_mean_squared_error improved from 30.91134 to 30.79792, saving model to ./temp_net.h5
# Epoch 46/50
# 140/140 [==============================] - 30s 214ms/step - loss: 815.5425 - root_mean_squared_error: 28.5575 - mae: 24.3385 - val_loss: 940.7772 - val_root_mean_squared_error: 30.6721 - val_mae: 26.7163
#
# Epoch 00046: val_root_mean_squared_error improved from 30.79792 to 30.67209, saving model to ./temp_net.h5
# Epoch 47/50
# 140/140 [==============================] - 30s 214ms/step - loss: 811.6924 - root_mean_squared_error: 28.4892 - mae: 24.1321 - val_loss: 935.9185 - val_root_mean_squared_error: 30.5928 - val_mae: 26.6157
#
# Epoch 00047: val_root_mean_squared_error improved from 30.67209 to 30.59278, saving model to ./temp_net.h5
# Epoch 48/50
# 140/140 [==============================] - 30s 214ms/step - loss: 810.0503 - root_mean_squared_error: 28.4605 - mae: 24.1033 - val_loss: 926.2820 - val_root_mean_squared_error: 30.4349 - val_mae: 26.4457
#
# Epoch 00048: val_root_mean_squared_error improved from 30.59278 to 30.43488, saving model to ./temp_net.h5
# Epoch 49/50
# 140/140 [==============================] - 30s 214ms/step - loss: 800.8636 - root_mean_squared_error: 28.2988 - mae: 23.9860 - val_loss: 920.9294 - val_root_mean_squared_error: 30.3468 - val_mae: 26.3421
#
# Epoch 00049: val_root_mean_squared_error improved from 30.43488 to 30.34682, saving model to ./temp_net.h5
# Epoch 50/50
# 140/140 [==============================] - 30s 214ms/step - loss: 791.5854 - root_mean_squared_error: 28.1347 - mae: 23.8098 - val_loss: 915.3698 - val_root_mean_squared_error: 30.2551 - val_mae: 26.2384
#
# Epoch 00050: val_root_mean_squared_error improved from 30.34682 to 30.25508, saving model to ./temp_net.h5
# val_rmse_min:  30.2551

# %%
# Test
rms, score = mlps_net.test_net(trained_net)
# Out:
#         y_pred  y_truth       diff  diff(ratio)     diff(%)       rmse
# 0    90.011551     98.0   7.988449     0.081515    8.151479  25.229608
# 1    75.644539     69.0   6.644539     0.096298    9.629766  25.229608
# 2    81.600060     82.0   0.399940     0.004877    0.487732  25.229608
# 3    74.169113     91.0  16.830887     0.184955   18.495481  25.229608
# 4    92.499741     93.0   0.500259     0.005379    0.537913  25.229608
# 5    96.652283     91.0   5.652283     0.062113    6.211300  25.229608
# 6    85.572571     95.0   9.427429     0.099236    9.923610  25.229608
# 7    93.994232    111.0  17.005768     0.153205   15.320511  25.229608
# 8    91.526062     96.0   4.473938     0.046604    4.660352  25.229608
# 9    67.369820     97.0  29.630180     0.305466   30.546579  25.229608
# 10   70.743088    124.0  53.256912     0.429491   42.949123  25.229608
# 11   78.491646     95.0  16.508354     0.173772   17.377216  25.229608
# 12   96.454903    107.0  10.545097     0.098552    9.855231  25.229608
# 13   98.806526     83.0  15.806526     0.190440   19.044008  25.229608
# 14   90.044991     84.0   6.044991     0.071964    7.196417  25.229608
# 15   72.148186     50.0  22.148186     0.442964   44.296371  25.229608
# 16   24.344868     28.0   3.655132     0.130540   13.054045  25.229608
# 17   87.345123     87.0   0.345123     0.003967    0.396693  25.229608
# 18   52.308491     16.0  36.308491     2.269281  226.928070  25.229608
# 19   72.610382     57.0  15.610382     0.273866   27.386635  25.229608
# 20  104.000183    111.0   6.999817     0.063061    6.306142  25.229608
# 21  101.431557    113.0  11.568443     0.102376   10.237560  25.229608
# 22   18.197205     20.0   1.802795     0.090140    9.013977  25.229608
# 23   92.689095    125.0  32.310905     0.258487   25.848726  25.229608
# 24  103.205849    119.0  15.794151     0.132724   13.272396  25.229608
# 25   75.826080     66.0   9.826080     0.148880   14.888000  25.229608
# 26   98.653244     97.0   1.653244     0.017044    1.704375  25.229608
# 27   98.869514     90.0   8.869514     0.098550    9.855017  25.229608
# 28   85.658363    115.0  29.341637     0.255145   25.514465  25.229608
# 29   29.781078      8.0  21.781078     2.722635  272.263489  25.229608
# 30   44.334522     48.0   3.665478     0.076364    7.636412  25.229608
# 31   99.681290    106.0   6.318710     0.059610    5.961048  25.229608
# 32    7.045703      7.0   0.045703     0.006529    0.652899  25.229608
# 33   62.539608     11.0  51.539608     4.685419  468.541901  25.229608
# 34   66.126488     19.0  47.126488     2.480341  248.034149  25.229608
# 35   32.013340     21.0  11.013340     0.524445   52.444477  25.229608
# 36   76.551460     50.0  26.551460     0.531029   53.102921  25.229608
# 37   88.080223    125.0  36.919777     0.295358   29.535822  25.229608
# 38   61.227848     28.0  33.227848     1.186709  118.670883  25.229608
# 39    3.852880     18.0  14.147120     0.785951   78.595116  25.229608
# 40   22.589054     10.0  12.589054     1.258905  125.890541  25.229608
# 41   90.432274     59.0  31.432274     0.532750   53.275043  25.229608
# 42   86.535454    109.0  22.464546     0.206097   20.609674  25.229608
# 43   67.954720    114.0  46.045280     0.403906   40.390594  25.229608
# 44  101.952057     47.0  54.952057     1.169193  116.919266  25.229608
# 45   95.053947    125.0  29.946053     0.239568   23.956842  25.229608
# 46   94.627708     92.0   2.627708     0.028562    2.856205  25.229608
# 47   72.799416     21.0  51.799416     2.466639  246.663879  25.229608
# 48   88.271370     79.0   9.271370     0.117359   11.735911  25.229608
# 49   94.453957    114.0  19.546043     0.171457   17.145651  25.229608
# 50   18.716351     29.0  10.283649     0.354609   35.460861  25.229608
# 51   43.059818     26.0  17.059818     0.656147   65.614685  25.229608
# 52   82.213722     97.0  14.786278     0.152436   15.243586  25.229608
# 53  100.138702    125.0  24.861298     0.198890   19.889038  25.229608
# 54   74.563240     15.0  59.563240     3.970883  397.088257  25.229608
# 55   66.157158    103.0  36.842842     0.357697   35.769749  25.229608
# 56   78.174812     37.0  41.174812     1.112833  111.283279  25.229608
# 57   99.972466    114.0  14.027534     0.123049   12.304855  25.229608
# 58   87.678619    100.0  12.321381     0.123214   12.321381  25.229608
# 59   46.347561     21.0  25.347561     1.207027  120.702675  25.229608
# 60   81.424232     54.0  27.424232     0.507856   50.785614  25.229608
# 61   89.433647     72.0  17.433647     0.242134   24.213400  25.229608
# 62   40.404732     28.0  12.404732     0.443026   44.302612  25.229608
# 63   72.724487    125.0  52.275513     0.418204   41.820412  25.229608
# 64   21.346035     14.0   7.346035     0.524717   52.471680  25.229608
# 65   95.910210     77.0  18.910210     0.245587   24.558714  25.229608
# 66   24.643074      8.0  16.643074     2.080384  208.038422  25.229608
# 67  108.249245    121.0  12.750755     0.105378   10.537814  25.229608
# 68   85.444786     94.0   8.555214     0.091013    9.101292  25.229608
# 69   94.803452    118.0  23.196548     0.196581   19.658092  25.229608
# 70   78.875557     50.0  28.875557     0.577511   57.751114  25.229608
# 71  113.333199    125.0  11.666801     0.093334    9.333442  25.229608
# 72   89.322891    125.0  35.677109     0.285417   28.541687  25.229608
# 73  108.650887    113.0   4.349113     0.038488    3.848773  25.229608
# 74   12.295431     10.0   2.295431     0.229543   22.954311  25.229608
# 75   46.840046     34.0  12.840046     0.377648   37.764843  25.229608
# 76   72.775894    107.0  34.224106     0.319851   31.985146  25.229608
# 77   84.686852     63.0  21.686852     0.344236   34.423576  25.229608
# 78   65.213364     90.0  24.786636     0.275407   27.540707  25.229608
# 79   37.219894      8.0  29.219894     3.652487  365.248688  25.229608
# 80    9.783066      9.0   0.783066     0.087007    8.700731  25.229608
# 81  103.920013    125.0  21.079987     0.168640   16.863991  25.229608
# 82   75.479897     58.0  17.479897     0.301378   30.137753  25.229608
# 83  101.188461    118.0  16.811539     0.142471   14.247067  25.229608
# 84   88.305702     89.0   0.694298     0.007801    0.780110  25.229608
# 85  103.418358    116.0  12.581642     0.108462   10.846243  25.229608
# 86  108.700821    115.0   6.299179     0.054775    5.477547  25.229608
# 87  104.435829    125.0  20.564171     0.164513   16.451336  25.229608
# 88   68.148590     28.0  40.148590     1.433878  143.387817  25.229608
# 89   72.782753     38.0  34.782753     0.915336   91.533562  25.229608
# 90  102.252846     20.0  82.252846     4.112642  411.264221  25.229608
# 91   79.084122     85.0   5.915878     0.069599    6.959857  25.229608
# 92   88.196678     55.0  33.196678     0.603576   60.357594  25.229608
# 93  117.832375    125.0   7.167625     0.057341    5.734100  25.229608
# 94  106.150391    125.0  18.849609     0.150797   15.079687  25.229608
# 95  103.786156     82.0  21.786156     0.265685   26.568481  25.229608
# 96   73.375206     59.0  14.375206     0.243648   24.364756  25.229608
# 97  102.361298    117.0  14.638702     0.125117   12.511711  25.229608
# 98   14.614631     20.0   5.385369     0.269268   26.926846  25.229608

# %%
print(subdataset + " test RMSE: ", rms)
print(subdataset + " test Score: ", score)
# Out:
# FD001 test RMSE:  25.22960844107264
# FD001 test Score:  5557.209936453776

# %% [markdown]
# # VGG + Weights + No Freeze

# %%
# Creo l'oggetto net
mlps_net = network_fit(train_samples, 
                       label_array_train, 
                       test_samples, 
                       label_array_test,
                       model_path = model_path, 
                       model_name = "vgg",
                       weights = True,
                       freeze = False,
                       verbose=verbose)
#Train
trained_net = mlps_net.train_net(epochs=epochs, batch_size=batch)
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 128, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 128, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 8193
# =================================================================
# Total params: 14,722,881
# Trainable params: 14,722,881
# Non-trainable params: 0
# _________________________________________________________________
# Initializing network...
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 128, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 128, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 8193
# =================================================================
# Total params: 14,722,881
# Trainable params: 14,722,881
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 140/140 [==============================] - 92s 625ms/step - loss: 2110.7685 - root_mean_squared_error: 44.2765 - mae: 36.0649 - val_loss: 578.6033 - val_root_mean_squared_error: 24.0542 - val_mae: 19.4404
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 24.05417, saving model to ./temp_net.h5
# Epoch 2/50
# 140/140 [==============================] - 85s 605ms/step - loss: 404.0644 - root_mean_squared_error: 20.0956 - mae: 15.8269 - val_loss: 511.1719 - val_root_mean_squared_error: 22.6091 - val_mae: 18.0684
#
# Epoch 00002: val_root_mean_squared_error improved from 24.05417 to 22.60911, saving model to ./temp_net.h5
# Epoch 3/50
# 140/140 [==============================] - 85s 607ms/step - loss: 298.0151 - root_mean_squared_error: 17.2587 - mae: 13.4456 - val_loss: 479.3333 - val_root_mean_squared_error: 21.8937 - val_mae: 17.1272
#
# Epoch 00003: val_root_mean_squared_error improved from 22.60911 to 21.89368, saving model to ./temp_net.h5
# Epoch 4/50
# 140/140 [==============================] - 86s 611ms/step - loss: 230.8836 - root_mean_squared_error: 15.1920 - mae: 11.8853 - val_loss: 511.2602 - val_root_mean_squared_error: 22.6111 - val_mae: 18.0892
#
# Epoch 00004: val_root_mean_squared_error did not improve from 21.89368
# Epoch 5/50
# 140/140 [==============================] - 85s 609ms/step - loss: 196.1387 - root_mean_squared_error: 14.0028 - mae: 11.0092 - val_loss: 555.3547 - val_root_mean_squared_error: 23.5660 - val_mae: 18.9885
#
# Epoch 00005: val_root_mean_squared_error did not improve from 21.89368
# Epoch 6/50
# 140/140 [==============================] - 85s 607ms/step - loss: 152.0329 - root_mean_squared_error: 12.3214 - mae: 9.6793 - val_loss: 554.3095 - val_root_mean_squared_error: 23.5438 - val_mae: 18.8204
#
# Epoch 00006: val_root_mean_squared_error did not improve from 21.89368
# Epoch 7/50
# 140/140 [==============================] - 85s 607ms/step - loss: 114.1509 - root_mean_squared_error: 10.6824 - mae: 8.3535 - val_loss: 484.9999 - val_root_mean_squared_error: 22.0227 - val_mae: 17.0531
#
# Epoch 00007: val_root_mean_squared_error did not improve from 21.89368
# Epoch 8/50
# 140/140 [==============================] - 85s 607ms/step - loss: 88.7434 - root_mean_squared_error: 9.4188 - mae: 7.3570 - val_loss: 491.4677 - val_root_mean_squared_error: 22.1691 - val_mae: 17.4432
#
# Epoch 00008: val_root_mean_squared_error did not improve from 21.89368
# Epoch 9/50
# 140/140 [==============================] - 85s 607ms/step - loss: 71.2097 - root_mean_squared_error: 8.4368 - mae: 6.5754 - val_loss: 501.7818 - val_root_mean_squared_error: 22.4005 - val_mae: 17.7347
#
# Epoch 00009: val_root_mean_squared_error did not improve from 21.89368
# Epoch 10/50
# 140/140 [==============================] - 85s 607ms/step - loss: 58.0991 - root_mean_squared_error: 7.6205 - mae: 5.9503 - val_loss: 542.0749 - val_root_mean_squared_error: 23.2825 - val_mae: 18.6177
#
# Epoch 00010: val_root_mean_squared_error did not improve from 21.89368
# Epoch 11/50
# 140/140 [==============================] - 85s 607ms/step - loss: 49.6973 - root_mean_squared_error: 7.0480 - mae: 5.5350 - val_loss: 524.0775 - val_root_mean_squared_error: 22.8927 - val_mae: 18.2552
#
# Epoch 00011: val_root_mean_squared_error did not improve from 21.89368
# Epoch 12/50
# 140/140 [==============================] - 85s 608ms/step - loss: 40.5749 - root_mean_squared_error: 6.3683 - mae: 5.0124 - val_loss: 554.8831 - val_root_mean_squared_error: 23.5560 - val_mae: 18.9254
#
# Epoch 00012: val_root_mean_squared_error did not improve from 21.89368
# Epoch 13/50
# 140/140 [==============================] - 86s 615ms/step - loss: 34.9691 - root_mean_squared_error: 5.9101 - mae: 4.6566 - val_loss: 498.1673 - val_root_mean_squared_error: 22.3197 - val_mae: 17.8147
#
# Epoch 00013: val_root_mean_squared_error did not improve from 21.89368
# Epoch 14/50
# 140/140 [==============================] - 85s 611ms/step - loss: 28.5565 - root_mean_squared_error: 5.3388 - mae: 4.2148 - val_loss: 527.0741 - val_root_mean_squared_error: 22.9581 - val_mae: 18.4669
#
# Epoch 00014: val_root_mean_squared_error did not improve from 21.89368
# Epoch 15/50
# 140/140 [==============================] - 86s 614ms/step - loss: 26.3998 - root_mean_squared_error: 5.1353 - mae: 4.0706 - val_loss: 489.1395 - val_root_mean_squared_error: 22.1165 - val_mae: 17.4472
#
# Epoch 00015: val_root_mean_squared_error did not improve from 21.89368
# Epoch 16/50
# 140/140 [==============================] - 85s 611ms/step - loss: 21.4809 - root_mean_squared_error: 4.6322 - mae: 3.6566 - val_loss: 485.0246 - val_root_mean_squared_error: 22.0233 - val_mae: 17.3741
#
# Epoch 00016: val_root_mean_squared_error did not improve from 21.89368
# Epoch 17/50
# 140/140 [==============================] - 86s 612ms/step - loss: 18.6893 - root_mean_squared_error: 4.3200 - mae: 3.4125 - val_loss: 487.7755 - val_root_mean_squared_error: 22.0856 - val_mae: 17.4201
#
# Epoch 00017: val_root_mean_squared_error did not improve from 21.89368
# Epoch 18/50
# 140/140 [==============================] - 86s 612ms/step - loss: 17.7005 - root_mean_squared_error: 4.2063 - mae: 3.3232 - val_loss: 506.2180 - val_root_mean_squared_error: 22.4993 - val_mae: 17.9724
#
# Epoch 00018: val_root_mean_squared_error did not improve from 21.89368
# Epoch 19/50
# 140/140 [==============================] - 86s 612ms/step - loss: 17.9410 - root_mean_squared_error: 4.2317 - mae: 3.3623 - val_loss: 493.1701 - val_root_mean_squared_error: 22.2074 - val_mae: 17.6040
#
# Epoch 00019: val_root_mean_squared_error did not improve from 21.89368
# Epoch 20/50
# 140/140 [==============================] - 86s 614ms/step - loss: 14.2673 - root_mean_squared_error: 3.7762 - mae: 2.9870 - val_loss: 484.2747 - val_root_mean_squared_error: 22.0062 - val_mae: 17.4740
#
# Epoch 00020: val_root_mean_squared_error did not improve from 21.89368
# Epoch 21/50
# 140/140 [==============================] - 86s 612ms/step - loss: 12.1362 - root_mean_squared_error: 3.4834 - mae: 2.7588 - val_loss: 485.4132 - val_root_mean_squared_error: 22.0321 - val_mae: 17.5083
#
# Epoch 00021: val_root_mean_squared_error did not improve from 21.89368
# Epoch 22/50
# 140/140 [==============================] - 86s 613ms/step - loss: 11.4519 - root_mean_squared_error: 3.3795 - mae: 2.6719 - val_loss: 490.5316 - val_root_mean_squared_error: 22.1479 - val_mae: 17.5431
#
# Epoch 00022: val_root_mean_squared_error did not improve from 21.89368
# Epoch 23/50
# 140/140 [==============================] - 86s 614ms/step - loss: 11.9768 - root_mean_squared_error: 3.4570 - mae: 2.7522 - val_loss: 501.0279 - val_root_mean_squared_error: 22.3837 - val_mae: 17.9284
#
# Epoch 00023: val_root_mean_squared_error did not improve from 21.89368
# Epoch 24/50
# 140/140 [==============================] - 86s 612ms/step - loss: 11.6961 - root_mean_squared_error: 3.4179 - mae: 2.7208 - val_loss: 498.5150 - val_root_mean_squared_error: 22.3274 - val_mae: 17.8461
#
# Epoch 00024: val_root_mean_squared_error did not improve from 21.89368
# Epoch 25/50
# 140/140 [==============================] - 85s 611ms/step - loss: 8.9314 - root_mean_squared_error: 2.9817 - mae: 2.3526 - val_loss: 499.8972 - val_root_mean_squared_error: 22.3584 - val_mae: 17.9171
#
# Epoch 00025: val_root_mean_squared_error did not improve from 21.89368
# Epoch 26/50
# 140/140 [==============================] - 86s 612ms/step - loss: 7.3322 - root_mean_squared_error: 2.7064 - mae: 2.1433 - val_loss: 475.2873 - val_root_mean_squared_error: 21.8011 - val_mae: 17.3309
#
# Epoch 00026: val_root_mean_squared_error improved from 21.89368 to 21.80108, saving model to ./temp_net.h5
# Epoch 27/50
# 140/140 [==============================] - 86s 611ms/step - loss: 7.3320 - root_mean_squared_error: 2.7071 - mae: 2.1552 - val_loss: 482.2317 - val_root_mean_squared_error: 21.9598 - val_mae: 17.4455
#
# Epoch 00027: val_root_mean_squared_error did not improve from 21.80108
# Epoch 28/50
# 140/140 [==============================] - 86s 613ms/step - loss: 6.3583 - root_mean_squared_error: 2.5212 - mae: 2.0022 - val_loss: 482.2898 - val_root_mean_squared_error: 21.9611 - val_mae: 17.4806
#
# Epoch 00028: val_root_mean_squared_error did not improve from 21.80108
# Epoch 29/50
# 140/140 [==============================] - 86s 611ms/step - loss: 6.1902 - root_mean_squared_error: 2.4796 - mae: 1.9565 - val_loss: 484.7998 - val_root_mean_squared_error: 22.0182 - val_mae: 17.5238
#
# Epoch 00029: val_root_mean_squared_error did not improve from 21.80108
# Epoch 30/50
# 140/140 [==============================] - 85s 611ms/step - loss: 4.6225 - root_mean_squared_error: 2.1495 - mae: 1.7102 - val_loss: 500.6841 - val_root_mean_squared_error: 22.3760 - val_mae: 17.8885
#
# Epoch 00030: val_root_mean_squared_error did not improve from 21.80108
# Epoch 31/50
# 140/140 [==============================] - 85s 611ms/step - loss: 4.8527 - root_mean_squared_error: 2.2007 - mae: 1.7414 - val_loss: 487.6953 - val_root_mean_squared_error: 22.0838 - val_mae: 17.5939
#
# Epoch 00031: val_root_mean_squared_error did not improve from 21.80108
# Epoch 32/50
# 140/140 [==============================] - 85s 611ms/step - loss: 5.0681 - root_mean_squared_error: 2.2497 - mae: 1.7861 - val_loss: 487.0411 - val_root_mean_squared_error: 22.0690 - val_mae: 17.6290
#
# Epoch 00032: val_root_mean_squared_error did not improve from 21.80108
# Epoch 33/50
# 140/140 [==============================] - 86s 611ms/step - loss: 4.3956 - root_mean_squared_error: 2.0955 - mae: 1.6694 - val_loss: 478.3565 - val_root_mean_squared_error: 21.8714 - val_mae: 17.3753
#
# Epoch 00033: val_root_mean_squared_error did not improve from 21.80108
# Epoch 34/50
# 140/140 [==============================] - 86s 611ms/step - loss: 4.6414 - root_mean_squared_error: 2.1477 - mae: 1.7008 - val_loss: 480.5164 - val_root_mean_squared_error: 21.9207 - val_mae: 17.3032
#
# Epoch 00034: val_root_mean_squared_error did not improve from 21.80108
# Epoch 35/50
# 140/140 [==============================] - 86s 614ms/step - loss: 4.3939 - root_mean_squared_error: 2.0891 - mae: 1.6669 - val_loss: 476.6506 - val_root_mean_squared_error: 21.8323 - val_mae: 17.2189
# Epoch 00035: val_root_mean_squared_error did not improve from 21.80108
# Epoch 36/50
# 140/140 [==============================] - 86s 613ms/step - loss: 4.0475 - root_mean_squared_error: 2.0100 - mae: 1.6041 - val_loss: 480.5533 - val_root_mean_squared_error: 21.9215 - val_mae: 17.3480
#
# Epoch 00036: val_root_mean_squared_error did not improve from 21.80108
# Epoch 37/50
# 140/140 [==============================] - 85s 610ms/step - loss: 3.7832 - root_mean_squared_error: 1.9426 - mae: 1.5390 - val_loss: 496.2868 - val_root_mean_squared_error: 22.2775 - val_mae: 17.8665
#
# Epoch 00037: val_root_mean_squared_error did not improve from 21.80108
# Epoch 38/50
# 140/140 [==============================] - 86s 613ms/step - loss: 4.5182 - root_mean_squared_error: 2.1237 - mae: 1.6797 - val_loss: 504.2798 - val_root_mean_squared_error: 22.4562 - val_mae: 18.0020
#
# Epoch 00038: val_root_mean_squared_error did not improve from 21.80108
# Epoch 39/50
# 140/140 [==============================] - 86s 611ms/step - loss: 4.5159 - root_mean_squared_error: 2.1104 - mae: 1.6856 - val_loss: 492.1779 - val_root_mean_squared_error: 22.1851 - val_mae: 17.7330
#
# Epoch 00039: val_root_mean_squared_error did not improve from 21.80108
# Epoch 40/50
# 140/140 [==============================] - 86s 611ms/step - loss: 2.4592 - root_mean_squared_error: 1.5670 - mae: 1.2466 - val_loss: 495.2435 - val_root_mean_squared_error: 22.2541 - val_mae: 17.8066
#
# Epoch 00040: val_root_mean_squared_error did not improve from 21.80108
# Epoch 41/50
# 140/140 [==============================] - 85s 610ms/step - loss: 3.2240 - root_mean_squared_error: 1.7940 - mae: 1.4305 - val_loss: 495.3376 - val_root_mean_squared_error: 22.2562 - val_mae: 17.8036
#
# Epoch 00041: val_root_mean_squared_error did not improve from 21.80108
# Epoch 42/50
# 140/140 [==============================] - 86s 611ms/step - loss: 2.1960 - root_mean_squared_error: 1.4785 - mae: 1.1748 - val_loss: 478.6534 - val_root_mean_squared_error: 21.8781 - val_mae: 17.3949
#
# Epoch 00042: val_root_mean_squared_error did not improve from 21.80108
# Epoch 43/50
# 140/140 [==============================] - 85s 610ms/step - loss: 1.8904 - root_mean_squared_error: 1.3746 - mae: 1.0902 - val_loss: 484.5862 - val_root_mean_squared_error: 22.0133 - val_mae: 17.5742
#
# Epoch 00043: val_root_mean_squared_error did not improve from 21.80108
# Epoch 44/50
# 140/140 [==============================] - 86s 611ms/step - loss: 3.3176 - root_mean_squared_error: 1.8199 - mae: 1.4590 - val_loss: 471.4805 - val_root_mean_squared_error: 21.7136 - val_mae: 17.1012
#
# Epoch 00044: val_root_mean_squared_error improved from 21.80108 to 21.71360, saving model to ./temp_net.h5
# Epoch 45/50
# 140/140 [==============================] - 86s 612ms/step - loss: 3.5817 - root_mean_squared_error: 1.8624 - mae: 1.4764 - val_loss: 481.3554 - val_root_mean_squared_error: 21.9398 - val_mae: 17.4940
#
# Epoch 00045: val_root_mean_squared_error did not improve from 21.71360
# Epoch 46/50
# 140/140 [==============================] - 86s 612ms/step - loss: 1.8739 - root_mean_squared_error: 1.3664 - mae: 1.0849 - val_loss: 476.8945 - val_root_mean_squared_error: 21.8379 - val_mae: 17.3276
#
# Epoch 00046: val_root_mean_squared_error did not improve from 21.71360
# Epoch 47/50
# 140/140 [==============================] - 86s 612ms/step - loss: 2.6755 - root_mean_squared_error: 1.6332 - mae: 1.2948 - val_loss: 478.9223 - val_root_mean_squared_error: 21.8843 - val_mae: 17.4578
#
# Epoch 00047: val_root_mean_squared_error did not improve from 21.71360
# Epoch 48/50
# 140/140 [==============================] - 86s 611ms/step - loss: 2.0732 - root_mean_squared_error: 1.4378 - mae: 1.1412 - val_loss: 492.6327 - val_root_mean_squared_error: 22.1953 - val_mae: 17.7863
#
# Epoch 00048: val_root_mean_squared_error did not improve from 21.71360
# Epoch 49/50
# 140/140 [==============================] - 85s 610ms/step - loss: 2.7556 - root_mean_squared_error: 1.6576 - mae: 1.3272 - val_loss: 501.7465 - val_root_mean_squared_error: 22.3997 - val_mae: 17.9888
#
# Epoch 00049: val_root_mean_squared_error did not improve from 21.71360
# Epoch 50/50
# 140/140 [==============================] - 85s 611ms/step - loss: 3.3467 - root_mean_squared_error: 1.8225 - mae: 1.4615 - val_loss: 477.8503 - val_root_mean_squared_error: 21.8598 - val_mae: 17.3925
#
# Epoch 00050: val_root_mean_squared_error did not improve from 21.71360
# val_rmse_min:  21.7136

# %%
# Test
rms, score = mlps_net.test_net(trained_net)
# Out:
#         y_pred  y_truth       diff  diff(ratio)     diff(%)       rmse
# 0   139.682434     98.0  41.682434     0.425331   42.533096  19.632785
# 1    55.062035     69.0  13.937965     0.202000   20.199949  19.632785
# 2    94.932327     82.0  12.932327     0.157711   15.771132  19.632785
# 3   109.179764     91.0  18.179764     0.199778   19.977762  19.632785
# 4    98.057732     93.0   5.057732     0.054384    5.438421  19.632785
# 5   100.244339     91.0   9.244339     0.101586   10.158614  19.632785
# 6   122.040909     95.0  27.040909     0.284641   28.464115  19.632785
# 7    95.479385    111.0  15.520615     0.139825   13.982536  19.632785
# 8   101.608040     96.0   5.608040     0.058417    5.841708  19.632785
# 9   104.094559     97.0   7.094559     0.073140    7.313978  19.632785
# 10   83.496384    124.0  40.503616     0.326642   32.664207  19.632785
# 11   85.287605     95.0   9.712395     0.102236   10.223574  19.632785
# 12  116.155533    107.0   9.155533     0.085566    8.556573  19.632785
# 13  100.715775     83.0  17.715775     0.213443   21.344307  19.632785
# 14  109.064919     84.0  25.064919     0.298392   29.839188  19.632785
# 15   47.594707     50.0   2.405293     0.048106    4.810585  19.632785
# 16   16.371758     28.0  11.628242     0.415294   41.529438  19.632785
# 17  100.168091     87.0  13.168091     0.151357   15.135736  19.632785
# 18   22.672504     16.0   6.672504     0.417032   41.703152  19.632785
# 19   46.501961     57.0  10.498039     0.184176   18.417614  19.632785
# 20  127.234070    111.0  16.234070     0.146253   14.625289  19.632785
# 21  126.862648    113.0  13.862648     0.122678   12.267830  19.632785
# 22    6.606936     20.0  13.393064     0.669653   66.965324  19.632785
# 23  102.199570    125.0  22.800430     0.182403   18.240345  19.632785
# 24  115.312599    119.0   3.687401     0.030987    3.098656  19.632785
# 25   89.473015     66.0  23.473015     0.355652   35.565174  19.632785
# 26   99.832108     97.0   2.832108     0.029197    2.919698  19.632785
# 27  111.441895     90.0  21.441895     0.238243   23.824327  19.632785
# 28  122.062126    115.0   7.062126     0.061410    6.140979  19.632785
# 29   17.303528      8.0   9.303528     1.162941  116.294098  19.632785
# 30   19.052570     48.0  28.947430     0.603071   60.307144  19.632785
# 31  122.232254    106.0  16.232254     0.153134   15.313446  19.632785
# 32    3.927665      7.0   3.072335     0.438905   43.890499  19.632785
# 33   32.186653     11.0  21.186653     1.926059  192.605942  19.632785
# 34   41.727051     19.0  22.727051     1.196161  119.616058  19.632785
# 35   17.619953     21.0   3.380047     0.160955   16.095461  19.632785
# 36   55.747124     50.0   5.747124     0.114942   11.494247  19.632785
# 37  114.386566    125.0  10.613434     0.084907    8.490747  19.632785
# 38   50.749271     28.0  22.749271     0.812474   81.247398  19.632785
# 39   16.373127     18.0   1.626873     0.090382    9.038183  19.632785
# 40   10.296606     10.0   0.296606     0.029661    2.966061  19.632785
# 41  106.507500     59.0  47.507500     0.805212   80.521187  19.632785
# 42  100.413834    109.0   8.586166     0.078772    7.877217  19.632785
# 43   93.188393    114.0  20.811607     0.182558   18.255796  19.632785
# 44   49.425022     47.0   2.425022     0.051596    5.159622  19.632785
# 45  106.909874    125.0  18.090126     0.144721   14.472100  19.632785
# 46   99.307625     92.0   7.307625     0.079431    7.943071  19.632785
# 47   24.513908     21.0   3.513908     0.167329   16.732897  19.632785
# 48  105.191864     79.0  26.191864     0.331543   33.154259  19.632785
# 49  112.153313    114.0   1.846687     0.016199    1.619901  19.632785
# 50   24.011967     29.0   4.988033     0.172001   17.200115  19.632785
# 51   23.898787     26.0   2.101213     0.080816    8.081591  19.632785
# 52   97.231300     97.0   0.231300     0.002385    0.238454  19.632785
# 53  115.856323    125.0   9.143677     0.073149    7.314941  19.632785
# 54   41.714317     15.0  26.714317     1.780954  178.095444  19.632785
# 55   98.819389    103.0   4.180611     0.040588    4.058846  19.632785
# 56   59.577614     37.0  22.577614     0.610206   61.020576  19.632785
# 57  103.365967    114.0  10.634033     0.093281    9.328099  19.632785
# 58   95.361877    100.0   4.638123     0.046381    4.638123  19.632785
# 59    9.322054     21.0  11.677946     0.556093   55.609268  19.632785
# 60   39.189480     54.0  14.810520     0.274269   27.426889  19.632785
# 61  107.864922     72.0  35.864922     0.498124   49.812393  19.632785
# 62   15.588693     28.0  12.411307     0.443261   44.326096  19.632785
# 63  118.746819    125.0   6.253181     0.050025    5.002545  19.632785
# 64   22.346849     14.0   8.346849     0.596204   59.620350  19.632785
# 65  100.289215     77.0  23.289215     0.302457   30.245733  19.632785
# 66    0.013600      8.0   7.986400     0.998300   99.830002  19.632785
# 67  130.692993    121.0   9.692993     0.080107    8.010738  19.632785
# 68   97.299446     94.0   3.299446     0.035100    3.510049  19.632785
# 69  113.010406    118.0   4.989594     0.042285    4.228469  19.632785
# 70   73.552460     50.0  23.552460     0.471049   47.104919  19.632785
# 71  111.701073    125.0  13.298927     0.106391   10.639141  19.632785
# 72  101.734703    125.0  23.265297     0.186122   18.612238  19.632785
# 73   90.995705    113.0  22.004295     0.194728   19.472828  19.632785
# 74    6.829742     10.0   3.170258     0.317026   31.702581  19.632785
# 75   24.029100     34.0   9.970900     0.293262   29.326176  19.632785
# 76   80.292717    107.0  26.707283     0.249601   24.960079  19.632785
# 77   99.459900     63.0  36.459900     0.578729   57.872856  19.632785
# 78  103.140488     90.0  13.140488     0.146005   14.600542  19.632785
# 79   13.622297      8.0   5.622297     0.702787   70.278717  19.632785
# 80   10.846956      9.0   1.846956     0.205217   20.521736  19.632785
# 81   98.769989    125.0  26.230011     0.209840   20.984009  19.632785
# 82   75.089355     58.0  17.089355     0.294644   29.464405  19.632785
# 83  117.303238    118.0   0.696762     0.005905    0.590476  19.632785
# 84  114.493011     89.0  25.493011     0.286438   28.643835  19.632785
# 85  122.712318    116.0   6.712318     0.057865    5.786481  19.632785
# 86  126.184525    115.0  11.184525     0.097257    9.725674  19.632785
# 87  115.865829    125.0   9.134171     0.073073    7.307336  19.632785
# 88   18.504925     28.0   9.495075     0.339110   33.910984  19.632785
# 89   87.404678     38.0  49.404678     1.300123  130.012314  19.632785
# 90   70.639336     20.0  50.639336     2.531967  253.196671  19.632785
# 91   76.343513     85.0   8.656487     0.101841   10.184102  19.632785
# 92  112.811150     55.0  57.811150     1.051112  105.111183  19.632785
# 93  118.995438    125.0   6.004562     0.048037    4.803650  19.632785
# 94   79.436241    125.0  45.563759     0.364510   36.451004  19.632785
# 95   78.826767     82.0   3.173233     0.038698    3.869797  19.632785
# 96   99.108757     59.0  40.108757     0.679809   67.980942  19.632785
# 97  117.398071    117.0   0.398071     0.003402    0.340232  19.632785
# 98   14.346386     20.0   5.653614     0.282681   28.268068  19.632785

# %%
print(subdataset + " test RMSE: ", rms)
print(subdataset + " test Score: ", score)
# Out:
# FD001 test RMSE:  19.632784520473496
# FD001 test Score:  1237.9737591277471

# %% [markdown]
# # VGG + NoWeights + No Freeze

# %%
# Creo l'oggetto net
mlps_net = network_fit(train_samples, 
                       label_array_train, 
                       test_samples, 
                       label_array_test,
                       model_path = model_path, 
                       model_name = "vgg",
                       weights = False,
                       freeze = False,
                       verbose=verbose)
#Train
trained_net = mlps_net.train_net(epochs=epochs, batch_size=batch)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 128, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 128, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 8193
# =================================================================
# Total params: 14,722,881
# Trainable params: 14,722,881
# Non-trainable params: 0
# _________________________________________________________________
# Initializing network...
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 128, 128, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 128, 128, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 128, 128, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 64, 64, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 64, 64, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 64, 64, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 32, 32, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 32, 32, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 32, 32, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 16, 16, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 16, 16, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 16, 16, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 8, 8, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 8, 8, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 4, 4, 512)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 8193
# =================================================================
# Total params: 14,722,881
# Trainable params: 14,722,881
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 140/140 [==============================] - 86s 610ms/step - loss: 4717.2460 - root_mean_squared_error: 67.7123 - mae: 57.1465 - val_loss: 1822.7479 - val_root_mean_squared_error: 42.6937 - val_mae: 38.6662
#
# Epoch 00001: val_root_mean_squared_error improved from inf to 42.69365, saving model to ./temp_net.h5
# Epoch 2/50
# 140/140 [==============================] - 85s 607ms/step - loss: 1741.1461 - root_mean_squared_error: 41.7267 - mae: 36.9936 - val_loss: 1815.9197 - val_root_mean_squared_error: 42.6136 - val_mae: 38.6336
#
# Epoch 00002: val_root_mean_squared_error improved from 42.69365 to 42.61361, saving model to ./temp_net.h5
# Epoch 3/50
# 140/140 [==============================] - 85s 609ms/step - loss: 1706.2279 - root_mean_squared_error: 41.3063 - mae: 36.5202 - val_loss: 1725.5911 - val_root_mean_squared_error: 41.5402 - val_mae: 37.0265
#
# Epoch 00003: val_root_mean_squared_error improved from 42.61361 to 41.54024, saving model to ./temp_net.h5
# Epoch 4/50
# 140/140 [==============================] - 85s 610ms/step - loss: 1674.9435 - root_mean_squared_error: 40.9255 - mae: 36.2185 - val_loss: 1713.7112 - val_root_mean_squared_error: 41.3970 - val_mae: 37.3625
#
# Epoch 00004: val_root_mean_squared_error improved from 41.54024 to 41.39700, saving model to ./temp_net.h5
# Epoch 5/50
# 140/140 [==============================] - 85s 610ms/step - loss: 1640.0772 - root_mean_squared_error: 40.4969 - mae: 35.9784 - val_loss: 1592.8352 - val_root_mean_squared_error: 39.9103 - val_mae: 35.3846
#
# Epoch 00005: val_root_mean_squared_error improved from 41.39700 to 39.91034, saving model to ./temp_net.h5
# Epoch 6/50
# 140/140 [==============================] - 85s 609ms/step - loss: 1408.0471 - root_mean_squared_error: 37.5132 - mae: 33.0627 - val_loss: 1257.7540 - val_root_mean_squared_error: 35.4648 - val_mae: 31.2908
#
# Epoch 00006: val_root_mean_squared_error improved from 39.91034 to 35.46483, saving model to ./temp_net.h5
# Epoch 7/50
# 140/140 [==============================] - 85s 610ms/step - loss: 1013.2304 - root_mean_squared_error: 31.8167 - mae: 27.1248 - val_loss: 954.7339 - val_root_mean_squared_error: 30.8988 - val_mae: 27.0784
#
# Epoch 00007: val_root_mean_squared_error improved from 35.46483 to 30.89877, saving model to ./temp_net.h5
# Epoch 8/50
# 140/140 [==============================] - 86s 612ms/step - loss: 852.1921 - root_mean_squared_error: 29.1616 - mae: 24.2050 - val_loss: 1133.2714 - val_root_mean_squared_error: 33.6641 - val_mae: 27.6246
#
# Epoch 00008: val_root_mean_squared_error did not improve from 30.89877
# Epoch 9/50
# 140/140 [==============================] - 86s 611ms/step - loss: 652.4528 - root_mean_squared_error: 25.5139 - mae: 20.5020 - val_loss: 702.0506 - val_root_mean_squared_error: 26.4962 - val_mae: 21.7316
#
# Epoch 00009: val_root_mean_squared_error improved from 30.89877 to 26.49624, saving model to ./temp_net.h5
# Epoch 10/50
# 140/140 [==============================] - 85s 607ms/step - loss: 555.1035 - root_mean_squared_error: 23.5568 - mae: 18.6724 - val_loss: 649.0090 - val_root_mean_squared_error: 25.4757 - val_mae: 20.8108
#
# Epoch 00010: val_root_mean_squared_error improved from 26.49624 to 25.47566, saving model to ./temp_net.h5
# Epoch 11/50
# 140/140 [==============================] - 86s 611ms/step - loss: 558.5800 - root_mean_squared_error: 23.6321 - mae: 18.6220 - val_loss: 628.9846 - val_root_mean_squared_error: 25.0796 - val_mae: 18.9544
#
# Epoch 00011: val_root_mean_squared_error improved from 25.47566 to 25.07957, saving model to ./temp_net.h5
# Epoch 12/50
# 140/140 [==============================] - 85s 606ms/step - loss: 517.0854 - root_mean_squared_error: 22.7378 - mae: 17.9207 - val_loss: 918.9377 - val_root_mean_squared_error: 30.3140 - val_mae: 24.6128
#
# Epoch 00012: val_root_mean_squared_error did not improve from 25.07957
# Epoch 13/50
# 140/140 [==============================] - 85s 606ms/step - loss: 516.1041 - root_mean_squared_error: 22.7141 - mae: 17.8651 - val_loss: 620.2205 - val_root_mean_squared_error: 24.9042 - val_mae: 19.8901
#
# Epoch 00013: val_root_mean_squared_error improved from 25.07957 to 24.90423, saving model to ./temp_net.h5
# Epoch 14/50
# 140/140 [==============================] - 85s 609ms/step - loss: 553.9089 - root_mean_squared_error: 23.5232 - mae: 18.4022 - val_loss: 519.0148 - val_root_mean_squared_error: 22.7819 - val_mae: 18.0731
#
# Epoch 00014: val_root_mean_squared_error improved from 24.90423 to 22.78190, saving model to ./temp_net.h5
# Epoch 15/50
# 140/140 [==============================] - 85s 608ms/step - loss: 509.6578 - root_mean_squared_error: 22.5678 - mae: 17.7967 - val_loss: 556.3624 - val_root_mean_squared_error: 23.5873 - val_mae: 17.8558
#
# Epoch 00015: val_root_mean_squared_error did not improve from 22.78190
# Epoch 16/50
# 140/140 [==============================] - 86s 614ms/step - loss: 478.8666 - root_mean_squared_error: 21.8796 - mae: 17.1149 - val_loss: 489.5502 - val_root_mean_squared_error: 22.1258 - val_mae: 16.8873
#
# Epoch 00016: val_root_mean_squared_error improved from 22.78190 to 22.12578, saving model to ./temp_net.h5
# Epoch 17/50
# 140/140 [==============================] - 86s 611ms/step - loss: 454.9150 - root_mean_squared_error: 21.3284 - mae: 16.6346 - val_loss: 594.3705 - val_root_mean_squared_error: 24.3797 - val_mae: 19.8810
#
# Epoch 00017: val_root_mean_squared_error did not improve from 22.12578
# Epoch 18/50
# 140/140 [==============================] - 86s 616ms/step - loss: 501.6074 - root_mean_squared_error: 22.3773 - mae: 17.4334 - val_loss: 482.3134 - val_root_mean_squared_error: 21.9616 - val_mae: 16.7908
#
# Epoch 00018: val_root_mean_squared_error improved from 22.12578 to 21.96163, saving model to ./temp_net.h5
# Epoch 19/50
# 140/140 [==============================] - 85s 607ms/step - loss: 429.3272 - root_mean_squared_error: 20.7197 - mae: 16.1961 - val_loss: 532.7314 - val_root_mean_squared_error: 23.0810 - val_mae: 18.5453
#
# Epoch 00019: val_root_mean_squared_error did not improve from 21.96163
# Epoch 20/50
# 140/140 [==============================] - 85s 607ms/step - loss: 429.8340 - root_mean_squared_error: 20.7302 - mae: 16.0913 - val_loss: 459.9525 - val_root_mean_squared_error: 21.4465 - val_mae: 16.3021
#
# Epoch 00020: val_root_mean_squared_error improved from 21.96163 to 21.44650, saving model to ./temp_net.h5
# Epoch 21/50
# 140/140 [==============================] - 85s 607ms/step - loss: 428.4872 - root_mean_squared_error: 20.6968 - mae: 16.0736 - val_loss: 559.5412 - val_root_mean_squared_error: 23.6546 - val_mae: 18.9787
#
# Epoch 00021: val_root_mean_squared_error did not improve from 21.44650
# Epoch 22/50
# 140/140 [==============================] - 85s 608ms/step - loss: 424.5769 - root_mean_squared_error: 20.6037 - mae: 16.0369 - val_loss: 525.4962 - val_root_mean_squared_error: 22.9237 - val_mae: 18.3508
#
# Epoch 00022: val_root_mean_squared_error did not improve from 21.44650
# Epoch 23/50
# 140/140 [==============================] - 85s 607ms/step - loss: 407.9532 - root_mean_squared_error: 20.1941 - mae: 15.6349 - val_loss: 684.9391 - val_root_mean_squared_error: 26.1713 - val_mae: 21.5093
#
# Epoch 00023: val_root_mean_squared_error did not improve from 21.44650
# Epoch 24/50
# 140/140 [==============================] - 85s 611ms/step - loss: 416.3219 - root_mean_squared_error: 20.4017 - mae: 15.8273 - val_loss: 435.0251 - val_root_mean_squared_error: 20.8573 - val_mae: 15.8723
#
# Epoch 00024: val_root_mean_squared_error improved from 21.44650 to 20.85726, saving model to ./temp_net.h5
# Epoch 25/50
# 140/140 [==============================] - 85s 607ms/step - loss: 422.0985 - root_mean_squared_error: 20.5428 - mae: 15.8883 - val_loss: 439.8499 - val_root_mean_squared_error: 20.9726 - val_mae: 15.9030
#
# Epoch 00025: val_root_mean_squared_error did not improve from 20.85726
# Epoch 26/50
# 140/140 [==============================] - 85s 609ms/step - loss: 416.2626 - root_mean_squared_error: 20.4016 - mae: 15.8408 - val_loss: 465.7611 - val_root_mean_squared_error: 21.5815 - val_mae: 16.9189
#
# Epoch 00026: val_root_mean_squared_error did not improve from 20.85726
# Epoch 27/50
# 140/140 [==============================] - 85s 608ms/step - loss: 377.1791 - root_mean_squared_error: 19.4142 - mae: 14.9498 - val_loss: 441.3278 - val_root_mean_squared_error: 21.0078 - val_mae: 16.4610
#
# Epoch 00027: val_root_mean_squared_error did not improve from 20.85726
# Epoch 28/50
# 140/140 [==============================] - 85s 607ms/step - loss: 381.2855 - root_mean_squared_error: 19.5239 - mae: 15.1019 - val_loss: 486.1516 - val_root_mean_squared_error: 22.0488 - val_mae: 17.9067
#
# Epoch 00028: val_root_mean_squared_error did not improve from 20.85726
# Epoch 29/50
# 140/140 [==============================] - 85s 607ms/step - loss: 395.1387 - root_mean_squared_error: 19.8771 - mae: 15.3625 - val_loss: 427.2527 - val_root_mean_squared_error: 20.6701 - val_mae: 16.0715
#
# Epoch 00029: val_root_mean_squared_error improved from 20.85726 to 20.67009, saving model to ./temp_net.h5
# Epoch 30/50
# 140/140 [==============================] - 85s 607ms/step - loss: 374.6875 - root_mean_squared_error: 19.3551 - mae: 14.9079 - val_loss: 438.2174 - val_root_mean_squared_error: 20.9336 - val_mae: 15.6725
#
# Epoch 00030: val_root_mean_squared_error did not improve from 20.67009
# Epoch 31/50
# 140/140 [==============================] - 85s 607ms/step - loss: 369.2332 - root_mean_squared_error: 19.2132 - mae: 14.8329 - val_loss: 420.0201 - val_root_mean_squared_error: 20.4944 - val_mae: 15.9361
#
# Epoch 00031: val_root_mean_squared_error improved from 20.67009 to 20.49439, saving model to ./temp_net.h5
# Epoch 32/50
# 140/140 [==============================] - 85s 606ms/step - loss: 345.0125 - root_mean_squared_error: 18.5721 - mae: 14.2700 - val_loss: 438.5686 - val_root_mean_squared_error: 20.9420 - val_mae: 16.5981
#
# Epoch 00032: val_root_mean_squared_error did not improve from 20.49439
# Epoch 33/50
# 140/140 [==============================] - 85s 607ms/step - loss: 368.1030 - root_mean_squared_error: 19.1840 - mae: 14.8174 - val_loss: 406.3376 - val_root_mean_squared_error: 20.1578 - val_mae: 15.4211
#
# Epoch 00033: val_root_mean_squared_error improved from 20.49439 to 20.15782, saving model to ./temp_net.h5
# Epoch 34/50
# 140/140 [==============================] - 85s 607ms/step - loss: 342.9742 - root_mean_squared_error: 18.5149 - mae: 14.3195 - val_loss: 645.0085 - val_root_mean_squared_error: 25.3970 - val_mae: 20.9238
#
# Epoch 00034: val_root_mean_squared_error did not improve from 20.15782
# Epoch 35/50
# 140/140 [==============================] - 85s 607ms/step - loss: 368.6718 - root_mean_squared_error: 19.1908 - mae: 14.8205 - val_loss: 398.1597 - val_root_mean_squared_error: 19.9539 - val_mae: 15.4712
#
# Epoch 00035: val_root_mean_squared_error improved from 20.15782 to 19.95394, saving model to ./temp_net.h5
# Epoch 36/50
# 140/140 [==============================] - 85s 608ms/step - loss: 345.9619 - root_mean_squared_error: 18.5996 - mae: 14.3503 - val_loss: 395.2691 - val_root_mean_squared_error: 19.8814 - val_mae: 15.3843
#
# Epoch 00036: val_root_mean_squared_error improved from 19.95394 to 19.88137, saving model to ./temp_net.h5
# Epoch 37/50
# 140/140 [==============================] - 85s 608ms/step - loss: 321.4964 - root_mean_squared_error: 17.9233 - mae: 13.7462 - val_loss: 430.8465 - val_root_mean_squared_error: 20.7568 - val_mae: 16.4477
#
# Epoch 00037: val_root_mean_squared_error did not improve from 19.88137
# Epoch 38/50
# 140/140 [==============================] - 85s 609ms/step - loss: 319.1151 - root_mean_squared_error: 17.8619 - mae: 13.8691 - val_loss: 380.0841 - val_root_mean_squared_error: 19.4957 - val_mae: 14.7102
#
# Epoch 00038: val_root_mean_squared_error improved from 19.88137 to 19.49575, saving model to ./temp_net.h5
# Epoch 39/50
# 140/140 [==============================] - 85s 608ms/step - loss: 330.8012 - root_mean_squared_error: 18.1849 - mae: 13.8990 - val_loss: 391.3482 - val_root_mean_squared_error: 19.7825 - val_mae: 15.3925
#
# Epoch 00039: val_root_mean_squared_error did not improve from 19.49575
# Epoch 40/50
# 140/140 [==============================] - 85s 609ms/step - loss: 310.6043 - root_mean_squared_error: 17.6220 - mae: 13.5632 - val_loss: 393.0115 - val_root_mean_squared_error: 19.8245 - val_mae: 15.3992
#
# Epoch 00040: val_root_mean_squared_error did not improve from 19.49575
# Epoch 41/50
# 140/140 [==============================] - 85s 608ms/step - loss: 312.4151 - root_mean_squared_error: 17.6746 - mae: 13.6826 - val_loss: 383.5206 - val_root_mean_squared_error: 19.5837 - val_mae: 14.6954
#
# Epoch 00041: val_root_mean_squared_error did not improve from 19.49575
# Epoch 42/50
# 140/140 [==============================] - 85s 608ms/step - loss: 314.1224 - root_mean_squared_error: 17.7214 - mae: 13.5604 - val_loss: 394.4325 - val_root_mean_squared_error: 19.8603 - val_mae: 14.6768
#
# Epoch 00042: val_root_mean_squared_error did not improve from 19.49575
# Epoch 43/50
# 140/140 [==============================] - 85s 607ms/step - loss: 307.4179 - root_mean_squared_error: 17.5261 - mae: 13.4150 - val_loss: 379.6568 - val_root_mean_squared_error: 19.4848 - val_mae: 14.6283
#
# Epoch 00043: val_root_mean_squared_error improved from 19.49575 to 19.48478, saving model to ./temp_net.h5
# Epoch 44/50
# 140/140 [==============================] - 85s 608ms/step - loss: 309.5874 - root_mean_squared_error: 17.5927 - mae: 13.4479 - val_loss: 399.3596 - val_root_mean_squared_error: 19.9840 - val_mae: 15.8727
#
# Epoch 00044: val_root_mean_squared_error did not improve from 19.48478
# Epoch 45/50
# 140/140 [==============================] - 85s 608ms/step - loss: 316.8012 - root_mean_squared_error: 17.7973 - mae: 13.7105 - val_loss: 368.9203 - val_root_mean_squared_error: 19.2073 - val_mae: 14.5166
#
# Epoch 00045: val_root_mean_squared_error improved from 19.48478 to 19.20730, saving model to ./temp_net.h5
# Epoch 46/50
# 140/140 [==============================] - 85s 608ms/step - loss: 305.5526 - root_mean_squared_error: 17.4784 - mae: 13.3996 - val_loss: 408.5868 - val_root_mean_squared_error: 20.2135 - val_mae: 15.0846
#
# Epoch 00046: val_root_mean_squared_error did not improve from 19.20730
# Epoch 47/50
# 140/140 [==============================] - 85s 607ms/step - loss: 297.2230 - root_mean_squared_error: 17.2379 - mae: 13.3040 - val_loss: 378.6139 - val_root_mean_squared_error: 19.4580 - val_mae: 15.0529
#
# Epoch 00047: val_root_mean_squared_error did not improve from 19.20730
# Epoch 48/50
# 140/140 [==============================] - 85s 608ms/step - loss: 294.3545 - root_mean_squared_error: 17.1559 - mae: 13.2084 - val_loss: 390.9143 - val_root_mean_squared_error: 19.7716 - val_mae: 15.2048
#
# Epoch 00048: val_root_mean_squared_error did not improve from 19.20730
# Epoch 49/50
# 140/140 [==============================] - 85s 608ms/step - loss: 304.9031 - root_mean_squared_error: 17.4558 - mae: 13.4210 - val_loss: 366.4491 - val_root_mean_squared_error: 19.1429 - val_mae: 14.6489
#
# Epoch 00049: val_root_mean_squared_error improved from 19.20730 to 19.14286, saving model to ./temp_net.h5
# Epoch 50/50
# 140/140 [==============================] - 85s 607ms/step - loss: 279.5818 - root_mean_squared_error: 16.7195 - mae: 12.8578 - val_loss: 375.3803 - val_root_mean_squared_error: 19.3747 - val_mae: 14.8290
#
# Epoch 00050: val_root_mean_squared_error did not improve from 19.14286
# val_rmse_min:  19.1429

# %%
# Test
rms, score = mlps_net.test_net(trained_net)
# Out:
#         y_pred  y_truth       diff  diff(ratio)     diff(%)       rmse
# 0   118.363007     98.0  20.363007     0.207786   20.778578  17.457732
# 1    62.743458     69.0   6.256542     0.090675    9.067452  17.457732
# 2   110.702324     82.0  28.702324     0.350028   35.002834  17.457732
# 3    98.526848     91.0   7.526848     0.082713    8.271261  17.457732
# 4   105.324921     93.0  12.324921     0.132526   13.252603  17.457732
# 5    98.195442     91.0   7.195442     0.079071    7.907079  17.457732
# 6   102.614517     95.0   7.614517     0.080153    8.015281  17.457732
# 7   103.906059    111.0   7.093941     0.063909    6.390937  17.457732
# 8    95.679184     96.0   0.320816     0.003342    0.334183  17.457732
# 9    80.181946     97.0  16.818054     0.173382   17.338200  17.457732
# 10   89.921310    124.0  34.078690     0.274828   27.482813  17.457732
# 11   71.249222     95.0  23.750778     0.250008   25.000820  17.457732
# 12  130.530960    107.0  23.530960     0.219916   21.991550  17.457732
# 13   83.651115     83.0   0.651115     0.007845    0.784476  17.457732
# 14   98.256073     84.0  14.256073     0.169715   16.971516  17.457732
# 15   56.207676     50.0   6.207676     0.124154   12.415352  17.457732
# 16   24.445227     28.0   3.554773     0.126956   12.695620  17.457732
# 17   97.762444     87.0  10.762444     0.123706   12.370625  17.457732
# 18   16.144882     16.0   0.144882     0.009055    0.905514  17.457732
# 19   42.669132     57.0  14.330868     0.251419   25.141874  17.457732
# 20  125.949722    111.0  14.949722     0.134682   13.468218  17.457732
# 21  124.342636    113.0  11.342636     0.100377   10.037731  17.457732
# 22   16.195799     20.0   3.804201     0.190210   19.021006  17.457732
# 23  129.286316    125.0   4.286316     0.034291    3.429053  17.457732
# 24  115.285446    119.0   3.714554     0.031215    3.121474  17.457732
# 25   69.840027     66.0   3.840027     0.058182    5.818223  17.457732
# 26   90.875587     97.0   6.124413     0.063138    6.313828  17.457732
# 27  109.445374     90.0  19.445374     0.216060   21.605970  17.457732
# 28  101.656342    115.0  13.343658     0.116032   11.603181  17.457732
# 29   13.384121      8.0   5.384121     0.673015   67.301514  17.457732
# 30   27.428688     48.0  20.571312     0.428569   42.856899  17.457732
# 31  118.017006    106.0  12.017006     0.113368   11.336799  17.457732
# 32    0.632895      7.0   6.367105     0.909586   90.958641  17.457732
# 33   17.239660     11.0   6.239660     0.567242   56.724186  17.457732
# 34   37.704716     19.0  18.704716     0.984459   98.445877  17.457732
# 35   17.892618     21.0   3.107382     0.147971   14.797056  17.457732
# 36   46.532089     50.0   3.467911     0.069358    6.935822  17.457732
# 37  111.648743    125.0  13.351257     0.106810   10.681005  17.457732
# 38   77.155266     28.0  49.155266     1.755545  175.554520  17.457732
# 39    9.479337     18.0   8.520663     0.473370   47.337021  17.457732
# 40    4.140320     10.0   5.859680     0.585968   58.596794  17.457732
# 41  107.050743     59.0  48.050743     0.814419   81.441940  17.457732
# 42   95.217056    109.0  13.782944     0.126449   12.644902  17.457732
# 43   97.278221    114.0  16.721779     0.146682   14.668228  17.457732
# 44   50.054436     47.0   3.054436     0.064988    6.498799  17.457732
# 45   99.276161    125.0  25.723839     0.205791   20.579071  17.457732
# 46   84.257996     92.0   7.742004     0.084152    8.415222  17.457732
# 47   18.020090     21.0   2.979910     0.141900   14.190046  17.457732
# 48  102.608917     79.0  23.608917     0.298847   29.884705  17.457732
# 49  100.054688    114.0  13.945312     0.122327   12.232731  17.457732
# 50   18.228580     29.0  10.771420     0.371428   37.142826  17.457732
# 51   24.515686     26.0   1.484314     0.057089    5.708899  17.457732
# 52  108.171333     97.0  11.171333     0.115168   11.516838  17.457732
# 53  113.767021    125.0  11.232979     0.089864    8.986382  17.457732
# 54   32.271786     15.0  17.271786     1.151452  115.145241  17.457732
# 55   86.058998    103.0  16.941002     0.164476   16.447575  17.457732
# 56   63.871639     37.0  26.871639     0.726261   72.626053  17.457732
# 57   70.587906    114.0  43.412094     0.380808   38.080784  17.457732
# 58   98.576721    100.0   1.423279     0.014233    1.423279  17.457732
# 59   10.846836     21.0  10.153164     0.483484   48.348400  17.457732
# 60   34.535252     54.0  19.464748     0.360458   36.045830  17.457732
# 61  103.677315     72.0  31.677315     0.439963   43.996273  17.457732
# 62    9.521623     28.0  18.478378     0.659942   65.994209  17.457732
# 63  100.620934    125.0  24.379066     0.195033   19.503254  17.457732
# 64   27.001951     14.0  13.001951     0.928711   92.871078  17.457732
# 65   88.704697     77.0  11.704697     0.152009   15.200904  17.457732
# 66    6.047509      8.0   1.952491     0.244061   24.406141  17.457732
# 67  102.387764    121.0  18.612236     0.153820   15.382012  17.457732
# 68  104.750290     94.0  10.750290     0.114365   11.436479  17.457732
# 69  118.050461    118.0   0.050461     0.000428    0.042763  17.457732
# 70   72.169823     50.0  22.169823     0.443396   44.339645  17.457732
# 71   99.427658    125.0  25.572342     0.204579   20.457874  17.457732
# 72  112.876389    125.0  12.123611     0.096989    9.698890  17.457732
# 73  113.516266    113.0   0.516266     0.004569    0.456872  17.457732
# 74    6.881111     10.0   3.118889     0.311889   31.188892  17.457732
# 75   16.739382     34.0  17.260618     0.507665   50.766521  17.457732
# 76   91.629379    107.0  15.370621     0.143651   14.365067  17.457732
# 77   80.658691     63.0  17.658691     0.280297   28.029669  17.457732
# 78   74.317177     90.0  15.682823     0.174254   17.425360  17.457732
# 79   11.210723      8.0   3.210723     0.401340   40.134037  17.457732
# 80    3.159204      9.0   5.840796     0.648977   64.897728  17.457732
# 81  113.101021    125.0  11.898979     0.095192    9.519184  17.457732
# 82   81.813545     58.0  23.813545     0.410578   41.057838  17.457732
# 83  112.502747    118.0   5.497253     0.046587    4.658689  17.457732
# 84  110.962883     89.0  21.962883     0.246774   24.677397  17.457732
# 85  122.038620    116.0   6.038620     0.052057    5.205707  17.457732
# 86  113.681694    115.0   1.318306     0.011464    1.146353  17.457732
# 87  107.129425    125.0  17.870575     0.142965   14.296460  17.457732
# 88   23.464132     28.0   4.535868     0.161995   16.199528  17.457732
# 89   58.682163     38.0  20.682163     0.544267   54.426746  17.457732
# 90   46.633316     20.0  26.633316     1.331666  133.166580  17.457732
# 91   71.729286     85.0  13.270714     0.156126   15.612605  17.457732
# 92  101.159950     55.0  46.159950     0.839272   83.927185  17.457732
# 93  114.750778    125.0  10.249222     0.081994    8.199377  17.457732
# 94  109.561752    125.0  15.438248     0.123506   12.350598  17.457732
# 95   96.215721     82.0  14.215721     0.173362   17.336245  17.457732
# 96   96.262756     59.0  37.262756     0.631572   63.157211  17.457732
# 97  105.457344    117.0  11.542656     0.098655    9.865518  17.457732
# 98   12.519434     20.0   7.480566     0.374028   37.402828  17.457732

# %%
print(subdataset + " test RMSE: ", rms)
print(subdataset + " test Score: ", score)
# Out:
# FD001 test RMSE:  17.457731808638364
# FD001 test Score:  706.8942570732618
